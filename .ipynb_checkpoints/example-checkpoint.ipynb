# %% [markdown]
# # Kriging example
#
# Since the global data base we used cannot be shared, we demonstrate using freely
# available data from Assumpcao et al. (2013) for South America, how the codes
# can be used.
#
# For simplicity's sake we did not use two different categories here, but focused
# on the continental area instead, by simply discarding all points where the Moho
# depth is less than 30 km.

# %%
import numpy as np
import matplotlib.pyplot as plt

import clean_kriging
import sklearn.cluster as cluster

from func_dump import get_pairwise_geo_distance

import logging
logging.basicConfig(level=logging.DEBUG)

def test_cluster_size(point_data,max_size,do_plot=False,chosen_range=None,
        perc_levels=20):
    """Test effect of number of clusters on cluster radius and size
    """
    
    cluster_sizes = range(5,max_size,1)
    radius_1 = np.zeros((len(cluster_sizes),3))
    cluster_N = np.zeros((len(cluster_sizes),3))
    percentages = np.zeros((len(cluster_sizes),perc_levels+1))

    X = point_data
    Xsel = X
    pd = get_pairwise_geo_distance(Xsel[:,0],Xsel[:,1]) 

    for k,n_clusters in enumerate(cluster_sizes):
        model = cluster.AgglomerativeClustering(linkage='complete',affinity='precomputed',n_clusters=n_clusters)
        model.fit(pd)
        radius = np.zeros((n_clusters))
        cluster_members = np.zeros((n_clusters))
        for i,c in enumerate(np.unique(model.labels_)):
            ix = np.where(model.labels_==c)[0]
            radius[i] = 0.5*pd[np.ix_(ix,ix)].max()
            cluster_members[i] = np.sum(model.labels_==c)
        r1i,r1a,r1s = (radius.min(),radius.max(),radius.std())
        radius_1[k,0] = r1i
        radius_1[k,1] = r1a
        radius_1[k,2] = np.median(radius)
        percentages[k,:] = np.percentile(radius,np.linspace(0,100,perc_levels+1))
        
    radius_1 = radius_1*110.0
    percentages = percentages*110.0
    
    if do_plot:
        plt.plot(cluster_sizes,radius_1)

        for i in range(perc_levels):
            if i<perc_levels/2:
                alpha = (i+1)*2.0/perc_levels
            else:
                alpha = (perc_levels-i)*2.0/perc_levels
            plt.fill_between(cluster_sizes,percentages[:,i],percentages[:,i+1],
                alpha=alpha,facecolor='green',edgecolor='none')
    if not chosen_range is None:
        return cluster_sizes[np.argmin(np.abs(radius_1[:,2]-chosen_range))]


def cluster_map(krigor):
    """Visualize distribution spatial distribution of a cluster
    """
    fig = plt.figure(figsize=(7,11))

    Xsel = krigor.X
    
    model = krigor.cluster_results[0]
    n_clusters = model.n_clusters
    cmap = plt.cm.get_cmap("jet",n_clusters)
    
    clu = model.cluster_centers_
    pointsize = np.sqrt(np.bincount(model.labels_))
    
    for i in range(len(Xsel)):
        j = model.labels_[i]
        if (Xsel[i,0]*clu[j,0])<0 and np.abs(np.abs(clu[j,0])-180.0) < 10.0:
            continue
        plt.plot((Xsel[i,0],clu[j,0]),(Xsel[i,1],clu[j,1]),color=cmap(model.labels_[i]),alpha=0.5)
    
    print clu.shape,n_clusters,pointsize.shape
    
    plt.scatter(clu[:,0],clu[:,1],7.5*pointsize,np.linspace(0,n_clusters,n_clusters),'s',
                     alpha=1.0,cmap=cmap,edgecolor='r',linewidth=1.5)
    
    plt.scatter(Xsel[:,0],Xsel[:,1],2,model.labels_,cmap=cmap,alpha=1.0,edgecolor='k')  
    plt.axis('equal')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    #plt.xlim([-90,-20])

# %% [markdown]
# ## Data input
# We load the file shipped together with this example. See the inside of the files for references to the sources.

# %%
point_data = np.loadtxt("Seismic_Moho_Assumpcao.txt",delimiter=",")
point_data[:,2] = -0.001*point_data[:,2] 

point_data = point_data[point_data[:,2]>30.0,:]

lon = np.arange(np.round(point_data[:,0].min()),np.round(point_data[:,0].max()+1),1)
lat = np.arange(np.round(point_data[:,1].min()),np.round(point_data[:,1].max()+1),1)

lonGrid,latGrid = np.meshgrid(lon,lat)

# %% [markdown]
# ## Prior specification
# We want to use inverse gamma priors for nugget, sill and range. The inverse gamma distribution is defined in terms of the parameters $\alpha$ and $\beta$, which we derive here from a specified mean and variance.
#
# $$\mu = \mathrm{Mean} = \frac{\beta}{\alpha-1} \quad \text{and}\quad \sigma^2= \mathrm{var} = \frac{\beta^2}{(\alpha-1)^2(\alpha-2)}$$
#
# Thus,
#
# $$
# \alpha = 2 + \frac{\mu^2}{\sigma^2} \quad \text{and}\quad\beta = \frac{\mu^3}{\sigma^2} + \mu
# $$
#
# The variable `moments` contains mean and variance for all nugget, sill and range. The last dimension of `moments` would be used, if there are different categories (i.e. ocean vs. continent), but in this example this is not required.

# %%
moments = np.zeros((3,2,1))
moments[:,:,0] = np.array(((1.0,3.0**2),(40.0,40.0**2),(10.0,10.0**2)))
beta = moments[:,0,:]**3/moments[:,1,:]+moments[:,0,:]
alpha = 2 + moments[:,0,:]**2 / moments[:,1,:]

# %% [markdown]
# ## Clustering
# All important routines are contained in objects of the class `MLEKrigor`. Such an object is created by passing it longitude,latitude,value and category. In this example, all category values are simply zero. Any clustering algorithm from the scikit-learn package can be used. Any options contained in the dictionary `clusterOption` will be passed to the constructor.
#
# After clustering, the covariance parameters for all clusters are determined (`krigor._fit_all_clusters`).

# %%
cat = np.ones((point_data.shape[0]),dtype=int)

krigor = clean_kriging.MLEKrigor(point_data[:,0],point_data[:,1],point_data[:,2],cat)
clusterOptions=[{'linkage':'complete','affinity':'precomputed','n_clusters':16}]

krigor._cluster_points(cluster.AgglomerativeClustering,options=clusterOptions,use_pd=True)
krigor._detect_dupes()
krigor._fit_all_clusters(minNugget=0.5,minSill=1.0,
    hyperpars=np.dstack((alpha,beta)),prior="inv_gamma",maxRange=None)

    
krigDict = {"threshold":1,"lambda_w":1.0,"minSill":1.0,
            "minNugget":0.5,
           "maxAbsError":4.0,"maxRelError":2.0,"badPoints":None,
           "hyperPars":np.dstack((alpha,beta)),"prior":"inv_gamma",
           "blocks":10}
# Out:
# clean_kriging.py:119: RuntimeWarning: divide by zero encountered in log
#   return np.sum(-(hyperpars[:,0]+1)*np.log(vals) - hyperpars[:,1]/vals)
# clean_kriging.py:119: RuntimeWarning: divide by zero encountered in divide
#   return np.sum(-(hyperpars[:,0]+1)*np.log(vals) - hyperpars[:,1]/vals)
# clean_kriging.py:119: RuntimeWarning: invalid value encountered in subtract
#   return np.sum(-(hyperpars[:,0]+1)*np.log(vals) - hyperpars[:,1]/vals)

# %%
cluster_map(krigor)
# Out:
# (16L, 2L) 16 (16L,)

# %% [markdown]
# In this map, the individual points are connected with lines to their respective cluster center

# %% [markdown]
# ## Outlier detection
# This is the most time-consuming step. The routine `jacknife` performs the hold-one-out cross validation to detect possible outliers. Two criteria are used to determine if a point is an outlier.
#
# 1. The **absolute** prediction error needs to be 4 km or more.
# 2. The prediction error is twice as high as the estimated error.
#
# This is controlled by the variables `maxAbsErr` and `maxRelErr` passed to the function `jacknife`. The third parameter ($\lambda_w$) controls how the covariance parameters are interpolated.
#
# There are two rounds of outlier detection (see main text for explanation).

# %%
sigma1,new_chosen = krigor.jacknife(4.0,2.0,100.0)
krigor.chosen_points = new_chosen.copy()
krigor._fit_all_clusters(minNugget=0.5,minSill=1.0,
        hyperpars=krigDict["hyperPars"],prior="inv_gamma",maxRange=None)  
        
sigma2,new_new_chosen = krigor.jacknife(4.0,2.0,100.0)
krigor.chosen_points = new_new_chosen.copy()
krigor._fit_all_clusters(minNugget=0.5,minSill=1.0,
        hyperpars=krigDict["hyperPars"],prior="inv_gamma",maxRange=None)
# Out:
# clean_kriging.py:119: RuntimeWarning: divide by zero encountered in log
#   return np.sum(-(hyperpars[:,0]+1)*np.log(vals) - hyperpars[:,1]/vals)
# clean_kriging.py:119: RuntimeWarning: divide by zero encountered in divide
#   return np.sum(-(hyperpars[:,0]+1)*np.log(vals) - hyperpars[:,1]/vals)
# clean_kriging.py:119: RuntimeWarning: invalid value encountered in subtract
#   return np.sum(-(hyperpars[:,0]+1)*np.log(vals) - hyperpars[:,1]/vals)
# INFO:root:Jacknife category 0 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/146
# DEBUG:root:Jacknife_kriging_all_chosen: 1/146
# DEBUG:root:Jacknife_kriging_all_chosen: 2/146
# DEBUG:root:Jacknife_kriging_all_chosen: 3/146
# DEBUG:root:Jacknife_kriging_all_chosen: 4/146
# DEBUG:root:Jacknife_kriging_all_chosen: 5/146
# DEBUG:root:Jacknife_kriging_all_chosen: 6/146
# DEBUG:root:Jacknife_kriging_all_chosen: 7/146
# DEBUG:root:Jacknife_kriging_all_chosen: 8/146
# DEBUG:root:Jacknife_kriging_all_chosen: 9/146
# DEBUG:root:Jacknife_kriging_all_chosen: 10/146
# DEBUG:root:Jacknife_kriging_all_chosen: 11/146
# DEBUG:root:Jacknife_kriging_all_chosen: 12/146
# DEBUG:root:Jacknife_kriging_all_chosen: 13/146
# DEBUG:root:Jacknife_kriging_all_chosen: 14/146
# DEBUG:root:Jacknife_kriging_all_chosen: 15/146
# DEBUG:root:Jacknife_kriging_all_chosen: 16/146
# DEBUG:root:Jacknife_kriging_all_chosen: 17/146
# DEBUG:root:Jacknife_kriging_all_chosen: 18/146
# DEBUG:root:Jacknife_kriging_all_chosen: 19/146
# DEBUG:root:Jacknife_kriging_all_chosen: 20/146
# DEBUG:root:Jacknife_kriging_all_chosen: 21/146
# DEBUG:root:Jacknife_kriging_all_chosen: 22/146
# DEBUG:root:Jacknife_kriging_all_chosen: 23/146
# DEBUG:root:Jacknife_kriging_all_chosen: 24/146
# DEBUG:root:Jacknife_kriging_all_chosen: 25/146
# DEBUG:root:Jacknife_kriging_all_chosen: 26/146
# DEBUG:root:Jacknife_kriging_all_chosen: 27/146
# DEBUG:root:Jacknife_kriging_all_chosen: 28/146
# DEBUG:root:Jacknife_kriging_all_chosen: 29/146
# DEBUG:root:Jacknife_kriging_all_chosen: 30/146
# DEBUG:root:Jacknife_kriging_all_chosen: 31/146
# DEBUG:root:Jacknife_kriging_all_chosen: 32/146
# DEBUG:root:Jacknife_kriging_all_chosen: 33/146
# DEBUG:root:Jacknife_kriging_all_chosen: 34/146
# DEBUG:root:Jacknife_kriging_all_chosen: 35/146
# DEBUG:root:Jacknife_kriging_all_chosen: 36/146
# DEBUG:root:Jacknife_kriging_all_chosen: 37/146
# DEBUG:root:Jacknife_kriging_all_chosen: 38/146
# DEBUG:root:Jacknife_kriging_all_chosen: 39/146
# DEBUG:root:Jacknife_kriging_all_chosen: 40/146
# DEBUG:root:Jacknife_kriging_all_chosen: 41/146
# DEBUG:root:Jacknife_kriging_all_chosen: 42/146
# DEBUG:root:Jacknife_kriging_all_chosen: 43/146
# DEBUG:root:Jacknife_kriging_all_chosen: 44/146
# DEBUG:root:Jacknife_kriging_all_chosen: 45/146
# DEBUG:root:Jacknife_kriging_all_chosen: 46/146
# DEBUG:root:Jacknife_kriging_all_chosen: 47/146
# DEBUG:root:Jacknife_kriging_all_chosen: 48/146
# DEBUG:root:Jacknife_kriging_all_chosen: 49/146
# DEBUG:root:Jacknife_kriging_all_chosen: 50/146
# DEBUG:root:Jacknife_kriging_all_chosen: 51/146
# DEBUG:root:Jacknife_kriging_all_chosen: 52/146
# DEBUG:root:Jacknife_kriging_all_chosen: 53/146
# DEBUG:root:Jacknife_kriging_all_chosen: 54/146
# DEBUG:root:Jacknife_kriging_all_chosen: 55/146
# DEBUG:root:Jacknife_kriging_all_chosen: 56/146
# DEBUG:root:Jacknife_kriging_all_chosen: 57/146
# DEBUG:root:Jacknife_kriging_all_chosen: 58/146
# DEBUG:root:Jacknife_kriging_all_chosen: 59/146
# DEBUG:root:Jacknife_kriging_all_chosen: 60/146
# DEBUG:root:Jacknife_kriging_all_chosen: 61/146
# DEBUG:root:Jacknife_kriging_all_chosen: 62/146
# DEBUG:root:Jacknife_kriging_all_chosen: 63/146
# DEBUG:root:Jacknife_kriging_all_chosen: 64/146
# DEBUG:root:Jacknife_kriging_all_chosen: 65/146
# DEBUG:root:Jacknife_kriging_all_chosen: 66/146
# DEBUG:root:Jacknife_kriging_all_chosen: 67/146
# DEBUG:root:Jacknife_kriging_all_chosen: 68/146
# DEBUG:root:Jacknife_kriging_all_chosen: 69/146
# DEBUG:root:Jacknife_kriging_all_chosen: 70/146
# DEBUG:root:Jacknife_kriging_all_chosen: 71/146
# DEBUG:root:Jacknife_kriging_all_chosen: 72/146
# DEBUG:root:Jacknife_kriging_all_chosen: 73/146
# DEBUG:root:Jacknife_kriging_all_chosen: 74/146
# DEBUG:root:Jacknife_kriging_all_chosen: 75/146
# DEBUG:root:Jacknife_kriging_all_chosen: 76/146
# DEBUG:root:Jacknife_kriging_all_chosen: 77/146
# DEBUG:root:Jacknife_kriging_all_chosen: 78/146
# DEBUG:root:Jacknife_kriging_all_chosen: 79/146
# DEBUG:root:Jacknife_kriging_all_chosen: 80/146
# DEBUG:root:Jacknife_kriging_all_chosen: 81/146
# DEBUG:root:Jacknife_kriging_all_chosen: 82/146
# DEBUG:root:Jacknife_kriging_all_chosen: 83/146
# DEBUG:root:Jacknife_kriging_all_chosen: 84/146
# DEBUG:root:Jacknife_kriging_all_chosen: 85/146
# DEBUG:root:Jacknife_kriging_all_chosen: 86/146
# DEBUG:root:Jacknife_kriging_all_chosen: 87/146
# DEBUG:root:Jacknife_kriging_all_chosen: 88/146
# DEBUG:root:Jacknife_kriging_all_chosen: 89/146
# DEBUG:root:Jacknife_kriging_all_chosen: 90/146
# DEBUG:root:Jacknife_kriging_all_chosen: 91/146
# DEBUG:root:Jacknife_kriging_all_chosen: 92/146
# DEBUG:root:Jacknife_kriging_all_chosen: 93/146
# DEBUG:root:Jacknife_kriging_all_chosen: 94/146
# DEBUG:root:Jacknife_kriging_all_chosen: 95/146
# DEBUG:root:Jacknife_kriging_all_chosen: 96/146
# DEBUG:root:Jacknife_kriging_all_chosen: 97/146
# DEBUG:root:Jacknife_kriging_all_chosen: 98/146
# DEBUG:root:Jacknife_kriging_all_chosen: 99/146
# DEBUG:root:Jacknife_kriging_all_chosen: 100/146
# DEBUG:root:Jacknife_kriging_all_chosen: 101/146
# DEBUG:root:Jacknife_kriging_all_chosen: 102/146
# DEBUG:root:Jacknife_kriging_all_chosen: 103/146
# DEBUG:root:Jacknife_kriging_all_chosen: 104/146
# DEBUG:root:Jacknife_kriging_all_chosen: 105/146
# DEBUG:root:Jacknife_kriging_all_chosen: 106/146
# DEBUG:root:Jacknife_kriging_all_chosen: 107/146
# DEBUG:root:Jacknife_kriging_all_chosen: 108/146
# DEBUG:root:Jacknife_kriging_all_chosen: 109/146
# DEBUG:root:Jacknife_kriging_all_chosen: 110/146
# DEBUG:root:Jacknife_kriging_all_chosen: 111/146
# DEBUG:root:Jacknife_kriging_all_chosen: 112/146
# DEBUG:root:Jacknife_kriging_all_chosen: 113/146
# DEBUG:root:Jacknife_kriging_all_chosen: 114/146
# DEBUG:root:Jacknife_kriging_all_chosen: 115/146
# DEBUG:root:Jacknife_kriging_all_chosen: 116/146
# DEBUG:root:Jacknife_kriging_all_chosen: 117/146
# DEBUG:root:Jacknife_kriging_all_chosen: 118/146
# DEBUG:root:Jacknife_kriging_all_chosen: 119/146
# DEBUG:root:Jacknife_kriging_all_chosen: 120/146
# DEBUG:root:Jacknife_kriging_all_chosen: 121/146
# DEBUG:root:Jacknife_kriging_all_chosen: 122/146
# DEBUG:root:Jacknife_kriging_all_chosen: 123/146
# DEBUG:root:Jacknife_kriging_all_chosen: 124/146
# DEBUG:root:Jacknife_kriging_all_chosen: 125/146
# DEBUG:root:Jacknife_kriging_all_chosen: 126/146
# DEBUG:root:Jacknife_kriging_all_chosen: 127/146
# DEBUG:root:Jacknife_kriging_all_chosen: 128/146
# DEBUG:root:Jacknife_kriging_all_chosen: 129/146
# DEBUG:root:Jacknife_kriging_all_chosen: 130/146
# DEBUG:root:Jacknife_kriging_all_chosen: 131/146
# DEBUG:root:Jacknife_kriging_all_chosen: 132/146
# DEBUG:root:Jacknife_kriging_all_chosen: 133/146
# DEBUG:root:Jacknife_kriging_all_chosen: 134/146
# DEBUG:root:Jacknife_kriging_all_chosen: 135/146
# DEBUG:root:Jacknife_kriging_all_chosen: 136/146
# DEBUG:root:Jacknife_kriging_all_chosen: 137/146
# DEBUG:root:Jacknife_kriging_all_chosen: 138/146
# DEBUG:root:Jacknife_kriging_all_chosen: 139/146
# DEBUG:root:Jacknife_kriging_all_chosen: 140/146
# DEBUG:root:Jacknife_kriging_all_chosen: 141/146
# DEBUG:root:Jacknife_kriging_all_chosen: 142/146
# DEBUG:root:Jacknife_kriging_all_chosen: 143/146
# DEBUG:root:Jacknife_kriging_all_chosen: 144/146
# DEBUG:root:Jacknife_kriging_all_chosen: 145/146
# INFO:root:Jacknife category 1 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/8
# DEBUG:root:Jacknife_kriging_all_chosen: 1/8
# DEBUG:root:Jacknife_kriging_all_chosen: 2/8
# DEBUG:root:Jacknife_kriging_all_chosen: 3/8
# DEBUG:root:Jacknife_kriging_all_chosen: 4/8
# DEBUG:root:Jacknife_kriging_all_chosen: 5/8
# DEBUG:root:Jacknife_kriging_all_chosen: 6/8
# DEBUG:root:Jacknife_kriging_all_chosen: 7/8
# INFO:root:Jacknife category 2 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/18
# DEBUG:root:Jacknife_kriging_all_chosen: 1/18
# DEBUG:root:Jacknife_kriging_all_chosen: 2/18
# DEBUG:root:Jacknife_kriging_all_chosen: 3/18
# DEBUG:root:Jacknife_kriging_all_chosen: 4/18
# DEBUG:root:Jacknife_kriging_all_chosen: 5/18
# DEBUG:root:Jacknife_kriging_all_chosen: 6/18
# DEBUG:root:Jacknife_kriging_all_chosen: 7/18
# DEBUG:root:Jacknife_kriging_all_chosen: 8/18
# DEBUG:root:Jacknife_kriging_all_chosen: 9/18
# DEBUG:root:Jacknife_kriging_all_chosen: 10/18
# DEBUG:root:Jacknife_kriging_all_chosen: 11/18
# DEBUG:root:Jacknife_kriging_all_chosen: 12/18
# DEBUG:root:Jacknife_kriging_all_chosen: 13/18
# DEBUG:root:Jacknife_kriging_all_chosen: 14/18
# DEBUG:root:Jacknife_kriging_all_chosen: 15/18
# DEBUG:root:Jacknife_kriging_all_chosen: 16/18
# DEBUG:root:Jacknife_kriging_all_chosen: 17/18
# INFO:root:Jacknife category 3 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/125
# DEBUG:root:Jacknife_kriging_all_chosen: 1/125
# DEBUG:root:Jacknife_kriging_all_chosen: 2/125
# DEBUG:root:Jacknife_kriging_all_chosen: 3/125
# DEBUG:root:Jacknife_kriging_all_chosen: 4/125
# DEBUG:root:Jacknife_kriging_all_chosen: 5/125
# DEBUG:root:Jacknife_kriging_all_chosen: 6/125
# DEBUG:root:Jacknife_kriging_all_chosen: 7/125
# DEBUG:root:Jacknife_kriging_all_chosen: 8/125
# DEBUG:root:Jacknife_kriging_all_chosen: 9/125
# DEBUG:root:Jacknife_kriging_all_chosen: 10/125
# DEBUG:root:Jacknife_kriging_all_chosen: 11/125
# DEBUG:root:Jacknife_kriging_all_chosen: 12/125
# DEBUG:root:Jacknife_kriging_all_chosen: 13/125
# DEBUG:root:Jacknife_kriging_all_chosen: 14/125
# DEBUG:root:Jacknife_kriging_all_chosen: 15/125
# DEBUG:root:Jacknife_kriging_all_chosen: 16/125
# DEBUG:root:Jacknife_kriging_all_chosen: 17/125
# DEBUG:root:Jacknife_kriging_all_chosen: 18/125
# DEBUG:root:Jacknife_kriging_all_chosen: 19/125
# DEBUG:root:Jacknife_kriging_all_chosen: 20/125
# DEBUG:root:Jacknife_kriging_all_chosen: 21/125
# DEBUG:root:Jacknife_kriging_all_chosen: 22/125
# DEBUG:root:Jacknife_kriging_all_chosen: 23/125
# DEBUG:root:Jacknife_kriging_all_chosen: 24/125
# DEBUG:root:Jacknife_kriging_all_chosen: 25/125
# DEBUG:root:Jacknife_kriging_all_chosen: 26/125
# DEBUG:root:Jacknife_kriging_all_chosen: 27/125
# DEBUG:root:Jacknife_kriging_all_chosen: 28/125
# DEBUG:root:Jacknife_kriging_all_chosen: 29/125
# DEBUG:root:Jacknife_kriging_all_chosen: 30/125
# DEBUG:root:Jacknife_kriging_all_chosen: 31/125
# DEBUG:root:Jacknife_kriging_all_chosen: 32/125
# DEBUG:root:Jacknife_kriging_all_chosen: 33/125
# DEBUG:root:Jacknife_kriging_all_chosen: 34/125
# DEBUG:root:Jacknife_kriging_all_chosen: 35/125
# DEBUG:root:Jacknife_kriging_all_chosen: 36/125
# DEBUG:root:Jacknife_kriging_all_chosen: 37/125
# DEBUG:root:Jacknife_kriging_all_chosen: 38/125
# DEBUG:root:Jacknife_kriging_all_chosen: 39/125
# DEBUG:root:Jacknife_kriging_all_chosen: 40/125
# DEBUG:root:Jacknife_kriging_all_chosen: 41/125
# DEBUG:root:Jacknife_kriging_all_chosen: 42/125
# DEBUG:root:Jacknife_kriging_all_chosen: 43/125
# DEBUG:root:Jacknife_kriging_all_chosen: 44/125
# DEBUG:root:Jacknife_kriging_all_chosen: 45/125
# DEBUG:root:Jacknife_kriging_all_chosen: 46/125
# DEBUG:root:Jacknife_kriging_all_chosen: 47/125
# DEBUG:root:Jacknife_kriging_all_chosen: 48/125
# DEBUG:root:Jacknife_kriging_all_chosen: 49/125
# DEBUG:root:Jacknife_kriging_all_chosen: 50/125
# DEBUG:root:Jacknife_kriging_all_chosen: 51/125
# DEBUG:root:Jacknife_kriging_all_chosen: 52/125
# DEBUG:root:Jacknife_kriging_all_chosen: 53/125
# DEBUG:root:Jacknife_kriging_all_chosen: 54/125
# DEBUG:root:Jacknife_kriging_all_chosen: 55/125
# DEBUG:root:Jacknife_kriging_all_chosen: 56/125
# DEBUG:root:Jacknife_kriging_all_chosen: 57/125
# DEBUG:root:Jacknife_kriging_all_chosen: 58/125
# DEBUG:root:Jacknife_kriging_all_chosen: 59/125
# DEBUG:root:Jacknife_kriging_all_chosen: 60/125
# DEBUG:root:Jacknife_kriging_all_chosen: 61/125
# DEBUG:root:Jacknife_kriging_all_chosen: 62/125
# DEBUG:root:Jacknife_kriging_all_chosen: 63/125
# DEBUG:root:Jacknife_kriging_all_chosen: 64/125
# DEBUG:root:Jacknife_kriging_all_chosen: 65/125
# DEBUG:root:Jacknife_kriging_all_chosen: 66/125
# DEBUG:root:Jacknife_kriging_all_chosen: 67/125
# DEBUG:root:Jacknife_kriging_all_chosen: 68/125
# DEBUG:root:Jacknife_kriging_all_chosen: 69/125
# DEBUG:root:Jacknife_kriging_all_chosen: 70/125
# DEBUG:root:Jacknife_kriging_all_chosen: 71/125
# DEBUG:root:Jacknife_kriging_all_chosen: 72/125
# DEBUG:root:Jacknife_kriging_all_chosen: 73/125
# DEBUG:root:Jacknife_kriging_all_chosen: 74/125
# DEBUG:root:Jacknife_kriging_all_chosen: 75/125
# DEBUG:root:Jacknife_kriging_all_chosen: 76/125
# DEBUG:root:Jacknife_kriging_all_chosen: 77/125
# DEBUG:root:Jacknife_kriging_all_chosen: 78/125
# DEBUG:root:Jacknife_kriging_all_chosen: 79/125
# DEBUG:root:Jacknife_kriging_all_chosen: 80/125
# DEBUG:root:Jacknife_kriging_all_chosen: 81/125
# DEBUG:root:Jacknife_kriging_all_chosen: 82/125
# DEBUG:root:Jacknife_kriging_all_chosen: 83/125
# DEBUG:root:Jacknife_kriging_all_chosen: 84/125
# DEBUG:root:Jacknife_kriging_all_chosen: 85/125
# DEBUG:root:Jacknife_kriging_all_chosen: 86/125
# DEBUG:root:Jacknife_kriging_all_chosen: 87/125
# DEBUG:root:Jacknife_kriging_all_chosen: 88/125
# DEBUG:root:Jacknife_kriging_all_chosen: 89/125
# DEBUG:root:Jacknife_kriging_all_chosen: 90/125
# DEBUG:root:Jacknife_kriging_all_chosen: 91/125
# DEBUG:root:Jacknife_kriging_all_chosen: 92/125
# DEBUG:root:Jacknife_kriging_all_chosen: 93/125
# DEBUG:root:Jacknife_kriging_all_chosen: 94/125
# DEBUG:root:Jacknife_kriging_all_chosen: 95/125
# DEBUG:root:Jacknife_kriging_all_chosen: 96/125
# DEBUG:root:Jacknife_kriging_all_chosen: 97/125
# DEBUG:root:Jacknife_kriging_all_chosen: 98/125
# DEBUG:root:Jacknife_kriging_all_chosen: 99/125
# DEBUG:root:Jacknife_kriging_all_chosen: 100/125
# DEBUG:root:Jacknife_kriging_all_chosen: 101/125
# DEBUG:root:Jacknife_kriging_all_chosen: 102/125
# DEBUG:root:Jacknife_kriging_all_chosen: 103/125
# DEBUG:root:Jacknife_kriging_all_chosen: 104/125
# DEBUG:root:Jacknife_kriging_all_chosen: 105/125
# DEBUG:root:Jacknife_kriging_all_chosen: 106/125
# DEBUG:root:Jacknife_kriging_all_chosen: 107/125
# DEBUG:root:Jacknife_kriging_all_chosen: 108/125
# DEBUG:root:Jacknife_kriging_all_chosen: 109/125
# DEBUG:root:Jacknife_kriging_all_chosen: 110/125
# DEBUG:root:Jacknife_kriging_all_chosen: 111/125
# DEBUG:root:Jacknife_kriging_all_chosen: 112/125
# DEBUG:root:Jacknife_kriging_all_chosen: 113/125
# DEBUG:root:Jacknife_kriging_all_chosen: 114/125
# DEBUG:root:Jacknife_kriging_all_chosen: 115/125
# DEBUG:root:Jacknife_kriging_all_chosen: 116/125
# DEBUG:root:Jacknife_kriging_all_chosen: 117/125
# DEBUG:root:Jacknife_kriging_all_chosen: 118/125
# DEBUG:root:Jacknife_kriging_all_chosen: 119/125
# DEBUG:root:Jacknife_kriging_all_chosen: 120/125
# DEBUG:root:Jacknife_kriging_all_chosen: 121/125
# DEBUG:root:Jacknife_kriging_all_chosen: 122/125
# DEBUG:root:Jacknife_kriging_all_chosen: 123/125
# DEBUG:root:Jacknife_kriging_all_chosen: 124/125
# INFO:root:Jacknife category 4 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/40
# DEBUG:root:Jacknife_kriging_all_chosen: 1/40
# DEBUG:root:Jacknife_kriging_all_chosen: 2/40
# DEBUG:root:Jacknife_kriging_all_chosen: 3/40
# DEBUG:root:Jacknife_kriging_all_chosen: 4/40
# DEBUG:root:Jacknife_kriging_all_chosen: 5/40
# DEBUG:root:Jacknife_kriging_all_chosen: 6/40
# DEBUG:root:Jacknife_kriging_all_chosen: 7/40
# DEBUG:root:Jacknife_kriging_all_chosen: 8/40
# DEBUG:root:Jacknife_kriging_all_chosen: 9/40
# DEBUG:root:Jacknife_kriging_all_chosen: 10/40
# DEBUG:root:Jacknife_kriging_all_chosen: 11/40
# DEBUG:root:Jacknife_kriging_all_chosen: 12/40
# DEBUG:root:Jacknife_kriging_all_chosen: 13/40
# DEBUG:root:Jacknife_kriging_all_chosen: 14/40
# DEBUG:root:Jacknife_kriging_all_chosen: 15/40
# DEBUG:root:Jacknife_kriging_all_chosen: 16/40
# DEBUG:root:Jacknife_kriging_all_chosen: 17/40
# DEBUG:root:Jacknife_kriging_all_chosen: 18/40
# DEBUG:root:Jacknife_kriging_all_chosen: 19/40
# DEBUG:root:Jacknife_kriging_all_chosen: 20/40
# chosen 125 16 (16L,)
# not chosen 125 16 (16L,) (16L,)
# DEBUG:root:Jacknife_kriging_all_chosen: 21/40
# DEBUG:root:Jacknife_kriging_all_chosen: 22/40
# DEBUG:root:Jacknife_kriging_all_chosen: 23/40
# DEBUG:root:Jacknife_kriging_all_chosen: 24/40
# DEBUG:root:Jacknife_kriging_all_chosen: 25/40
# DEBUG:root:Jacknife_kriging_all_chosen: 26/40
# DEBUG:root:Jacknife_kriging_all_chosen: 27/40
# DEBUG:root:Jacknife_kriging_all_chosen: 28/40
# DEBUG:root:Jacknife_kriging_all_chosen: 29/40
# DEBUG:root:Jacknife_kriging_all_chosen: 30/40
# DEBUG:root:Jacknife_kriging_all_chosen: 31/40
# DEBUG:root:Jacknife_kriging_all_chosen: 32/40
# DEBUG:root:Jacknife_kriging_all_chosen: 33/40
# DEBUG:root:Jacknife_kriging_all_chosen: 34/40
# DEBUG:root:Jacknife_kriging_all_chosen: 35/40
# DEBUG:root:Jacknife_kriging_all_chosen: 36/40
# DEBUG:root:Jacknife_kriging_all_chosen: 37/40
# DEBUG:root:Jacknife_kriging_all_chosen: 38/40
# DEBUG:root:Jacknife_kriging_all_chosen: 39/40
# INFO:root:Jacknife category 5 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/58
# DEBUG:root:Jacknife_kriging_all_chosen: 1/58
# DEBUG:root:Jacknife_kriging_all_chosen: 2/58
# DEBUG:root:Jacknife_kriging_all_chosen: 3/58
# DEBUG:root:Jacknife_kriging_all_chosen: 4/58
# DEBUG:root:Jacknife_kriging_all_chosen: 5/58
# DEBUG:root:Jacknife_kriging_all_chosen: 6/58
# DEBUG:root:Jacknife_kriging_all_chosen: 7/58
# DEBUG:root:Jacknife_kriging_all_chosen: 8/58
# DEBUG:root:Jacknife_kriging_all_chosen: 9/58
# DEBUG:root:Jacknife_kriging_all_chosen: 10/58
# DEBUG:root:Jacknife_kriging_all_chosen: 11/58
# DEBUG:root:Jacknife_kriging_all_chosen: 12/58
# DEBUG:root:Jacknife_kriging_all_chosen: 13/58
# DEBUG:root:Jacknife_kriging_all_chosen: 14/58
# chosen 40 2 (2L,)
# not chosen 40 2 (2L,) (2L,)
# DEBUG:root:Jacknife_kriging_all_chosen: 15/58
# DEBUG:root:Jacknife_kriging_all_chosen: 16/58
# DEBUG:root:Jacknife_kriging_all_chosen: 17/58
# DEBUG:root:Jacknife_kriging_all_chosen: 18/58
# DEBUG:root:Jacknife_kriging_all_chosen: 19/58
# DEBUG:root:Jacknife_kriging_all_chosen: 20/58
# DEBUG:root:Jacknife_kriging_all_chosen: 21/58
# DEBUG:root:Jacknife_kriging_all_chosen: 22/58
# DEBUG:root:Jacknife_kriging_all_chosen: 23/58
# DEBUG:root:Jacknife_kriging_all_chosen: 24/58
# DEBUG:root:Jacknife_kriging_all_chosen: 25/58
# DEBUG:root:Jacknife_kriging_all_chosen: 26/58
# DEBUG:root:Jacknife_kriging_all_chosen: 27/58
# DEBUG:root:Jacknife_kriging_all_chosen: 28/58
# DEBUG:root:Jacknife_kriging_all_chosen: 29/58
# DEBUG:root:Jacknife_kriging_all_chosen: 30/58
# DEBUG:root:Jacknife_kriging_all_chosen: 31/58
# DEBUG:root:Jacknife_kriging_all_chosen: 32/58
# DEBUG:root:Jacknife_kriging_all_chosen: 33/58
# DEBUG:root:Jacknife_kriging_all_chosen: 34/58
# DEBUG:root:Jacknife_kriging_all_chosen: 35/58
# DEBUG:root:Jacknife_kriging_all_chosen: 36/58
# DEBUG:root:Jacknife_kriging_all_chosen: 37/58
# DEBUG:root:Jacknife_kriging_all_chosen: 38/58
# DEBUG:root:Jacknife_kriging_all_chosen: 39/58
# DEBUG:root:Jacknife_kriging_all_chosen: 40/58
# DEBUG:root:Jacknife_kriging_all_chosen: 41/58
# DEBUG:root:Jacknife_kriging_all_chosen: 42/58
# DEBUG:root:Jacknife_kriging_all_chosen: 43/58
# DEBUG:root:Jacknife_kriging_all_chosen: 44/58
# DEBUG:root:Jacknife_kriging_all_chosen: 45/58
# DEBUG:root:Jacknife_kriging_all_chosen: 46/58
# DEBUG:root:Jacknife_kriging_all_chosen: 47/58
# DEBUG:root:Jacknife_kriging_all_chosen: 48/58
# DEBUG:root:Jacknife_kriging_all_chosen: 49/58
# DEBUG:root:Jacknife_kriging_all_chosen: 50/58
# DEBUG:root:Jacknife_kriging_all_chosen: 51/58
# DEBUG:root:Jacknife_kriging_all_chosen: 52/58
# DEBUG:root:Jacknife_kriging_all_chosen: 53/58
# DEBUG:root:Jacknife_kriging_all_chosen: 54/58
# DEBUG:root:Jacknife_kriging_all_chosen: 55/58
# DEBUG:root:Jacknife_kriging_all_chosen: 56/58
# DEBUG:root:Jacknife_kriging_all_chosen: 57/58
# INFO:root:Jacknife category 6 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/19
# DEBUG:root:Jacknife_kriging_all_chosen: 1/19
# DEBUG:root:Jacknife_kriging_all_chosen: 2/19
# DEBUG:root:Jacknife_kriging_all_chosen: 3/19
# DEBUG:root:Jacknife_kriging_all_chosen: 4/19
# DEBUG:root:Jacknife_kriging_all_chosen: 5/19
# DEBUG:root:Jacknife_kriging_all_chosen: 6/19
# DEBUG:root:Jacknife_kriging_all_chosen: 7/19
# DEBUG:root:Jacknife_kriging_all_chosen: 8/19
# DEBUG:root:Jacknife_kriging_all_chosen: 9/19
# DEBUG:root:Jacknife_kriging_all_chosen: 10/19
# DEBUG:root:Jacknife_kriging_all_chosen: 11/19
# DEBUG:root:Jacknife_kriging_all_chosen: 12/19
# DEBUG:root:Jacknife_kriging_all_chosen: 13/19
# DEBUG:root:Jacknife_kriging_all_chosen: 14/19
# DEBUG:root:Jacknife_kriging_all_chosen: 15/19
# DEBUG:root:Jacknife_kriging_all_chosen: 16/19
# DEBUG:root:Jacknife_kriging_all_chosen: 17/19
# DEBUG:root:Jacknife_kriging_all_chosen: 18/19
# INFO:root:Jacknife category 7 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/31
# DEBUG:root:Jacknife_kriging_all_chosen: 1/31
# DEBUG:root:Jacknife_kriging_all_chosen: 2/31
# DEBUG:root:Jacknife_kriging_all_chosen: 3/31
# DEBUG:root:Jacknife_kriging_all_chosen: 4/31
# DEBUG:root:Jacknife_kriging_all_chosen: 5/31
# DEBUG:root:Jacknife_kriging_all_chosen: 6/31
# DEBUG:root:Jacknife_kriging_all_chosen: 7/31
# DEBUG:root:Jacknife_kriging_all_chosen: 8/31
# DEBUG:root:Jacknife_kriging_all_chosen: 9/31
# DEBUG:root:Jacknife_kriging_all_chosen: 10/31
# DEBUG:root:Jacknife_kriging_all_chosen: 11/31
# DEBUG:root:Jacknife_kriging_all_chosen: 12/31
# DEBUG:root:Jacknife_kriging_all_chosen: 13/31
# DEBUG:root:Jacknife_kriging_all_chosen: 14/31
# DEBUG:root:Jacknife_kriging_all_chosen: 15/31
# DEBUG:root:Jacknife_kriging_all_chosen: 16/31
# DEBUG:root:Jacknife_kriging_all_chosen: 17/31
# DEBUG:root:Jacknife_kriging_all_chosen: 18/31
# DEBUG:root:Jacknife_kriging_all_chosen: 19/31
# DEBUG:root:Jacknife_kriging_all_chosen: 20/31
# DEBUG:root:Jacknife_kriging_all_chosen: 21/31
# DEBUG:root:Jacknife_kriging_all_chosen: 22/31
# DEBUG:root:Jacknife_kriging_all_chosen: 23/31
# DEBUG:root:Jacknife_kriging_all_chosen: 24/31
# DEBUG:root:Jacknife_kriging_all_chosen: 25/31
# DEBUG:root:Jacknife_kriging_all_chosen: 26/31
# DEBUG:root:Jacknife_kriging_all_chosen: 27/31
# DEBUG:root:Jacknife_kriging_all_chosen: 28/31
# DEBUG:root:Jacknife_kriging_all_chosen: 29/31
# DEBUG:root:Jacknife_kriging_all_chosen: 30/31
# INFO:root:Jacknife category 8 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/62
# DEBUG:root:Jacknife_kriging_all_chosen: 1/62
# DEBUG:root:Jacknife_kriging_all_chosen: 2/62
# DEBUG:root:Jacknife_kriging_all_chosen: 3/62
# DEBUG:root:Jacknife_kriging_all_chosen: 4/62
# DEBUG:root:Jacknife_kriging_all_chosen: 5/62
# DEBUG:root:Jacknife_kriging_all_chosen: 6/62
# DEBUG:root:Jacknife_kriging_all_chosen: 7/62
# chosen 31 2 (2L,)
# not chosen 31 2 (2L,) (2L,)
# DEBUG:root:Jacknife_kriging_all_chosen: 8/62
# DEBUG:root:Jacknife_kriging_all_chosen: 9/62
# DEBUG:root:Jacknife_kriging_all_chosen: 10/62
# DEBUG:root:Jacknife_kriging_all_chosen: 11/62
# DEBUG:root:Jacknife_kriging_all_chosen: 12/62
# DEBUG:root:Jacknife_kriging_all_chosen: 13/62
# DEBUG:root:Jacknife_kriging_all_chosen: 14/62
# DEBUG:root:Jacknife_kriging_all_chosen: 15/62
# DEBUG:root:Jacknife_kriging_all_chosen: 16/62
# DEBUG:root:Jacknife_kriging_all_chosen: 17/62
# DEBUG:root:Jacknife_kriging_all_chosen: 18/62
# DEBUG:root:Jacknife_kriging_all_chosen: 19/62
# DEBUG:root:Jacknife_kriging_all_chosen: 20/62
# DEBUG:root:Jacknife_kriging_all_chosen: 21/62
# DEBUG:root:Jacknife_kriging_all_chosen: 22/62
# DEBUG:root:Jacknife_kriging_all_chosen: 23/62
# DEBUG:root:Jacknife_kriging_all_chosen: 24/62
# DEBUG:root:Jacknife_kriging_all_chosen: 25/62
# DEBUG:root:Jacknife_kriging_all_chosen: 26/62
# DEBUG:root:Jacknife_kriging_all_chosen: 27/62
# DEBUG:root:Jacknife_kriging_all_chosen: 28/62
# DEBUG:root:Jacknife_kriging_all_chosen: 29/62
# DEBUG:root:Jacknife_kriging_all_chosen: 30/62
# DEBUG:root:Jacknife_kriging_all_chosen: 31/62
# DEBUG:root:Jacknife_kriging_all_chosen: 32/62
# DEBUG:root:Jacknife_kriging_all_chosen: 33/62
# DEBUG:root:Jacknife_kriging_all_chosen: 34/62
# DEBUG:root:Jacknife_kriging_all_chosen: 35/62
# DEBUG:root:Jacknife_kriging_all_chosen: 36/62
# DEBUG:root:Jacknife_kriging_all_chosen: 37/62
# DEBUG:root:Jacknife_kriging_all_chosen: 38/62
# DEBUG:root:Jacknife_kriging_all_chosen: 39/62
# DEBUG:root:Jacknife_kriging_all_chosen: 40/62
# DEBUG:root:Jacknife_kriging_all_chosen: 41/62
# DEBUG:root:Jacknife_kriging_all_chosen: 42/62
# DEBUG:root:Jacknife_kriging_all_chosen: 43/62
# DEBUG:root:Jacknife_kriging_all_chosen: 44/62
# DEBUG:root:Jacknife_kriging_all_chosen: 45/62
# DEBUG:root:Jacknife_kriging_all_chosen: 46/62
# DEBUG:root:Jacknife_kriging_all_chosen: 47/62
# DEBUG:root:Jacknife_kriging_all_chosen: 48/62
# DEBUG:root:Jacknife_kriging_all_chosen: 49/62
# DEBUG:root:Jacknife_kriging_all_chosen: 50/62
# DEBUG:root:Jacknife_kriging_all_chosen: 51/62
# DEBUG:root:Jacknife_kriging_all_chosen: 52/62
# DEBUG:root:Jacknife_kriging_all_chosen: 53/62
# DEBUG:root:Jacknife_kriging_all_chosen: 54/62
# DEBUG:root:Jacknife_kriging_all_chosen: 55/62
# DEBUG:root:Jacknife_kriging_all_chosen: 56/62
# DEBUG:root:Jacknife_kriging_all_chosen: 57/62
# DEBUG:root:Jacknife_kriging_all_chosen: 58/62
# DEBUG:root:Jacknife_kriging_all_chosen: 59/62
# DEBUG:root:Jacknife_kriging_all_chosen: 60/62
# DEBUG:root:Jacknife_kriging_all_chosen: 61/62
# INFO:root:Jacknife category 9 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/10
# DEBUG:root:Jacknife_kriging_all_chosen: 1/10
# DEBUG:root:Jacknife_kriging_all_chosen: 2/10
# DEBUG:root:Jacknife_kriging_all_chosen: 3/10
# DEBUG:root:Jacknife_kriging_all_chosen: 4/10
# DEBUG:root:Jacknife_kriging_all_chosen: 5/10
# DEBUG:root:Jacknife_kriging_all_chosen: 6/10
# DEBUG:root:Jacknife_kriging_all_chosen: 7/10
# DEBUG:root:Jacknife_kriging_all_chosen: 8/10
# DEBUG:root:Jacknife_kriging_all_chosen: 9/10
# INFO:root:Jacknife category 10 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/5
# DEBUG:root:Jacknife_kriging_all_chosen: 1/5
# DEBUG:root:Jacknife_kriging_all_chosen: 2/5
# DEBUG:root:Jacknife_kriging_all_chosen: 3/5
# DEBUG:root:Jacknife_kriging_all_chosen: 4/5
# INFO:root:Jacknife category 11 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/17
# DEBUG:root:Jacknife_kriging_all_chosen: 1/17
# DEBUG:root:Jacknife_kriging_all_chosen: 2/17
# DEBUG:root:Jacknife_kriging_all_chosen: 3/17
# DEBUG:root:Jacknife_kriging_all_chosen: 4/17
# DEBUG:root:Jacknife_kriging_all_chosen: 5/17
# DEBUG:root:Jacknife_kriging_all_chosen: 6/17
# DEBUG:root:Jacknife_kriging_all_chosen: 7/17
# DEBUG:root:Jacknife_kriging_all_chosen: 8/17
# DEBUG:root:Jacknife_kriging_all_chosen: 9/17
# DEBUG:root:Jacknife_kriging_all_chosen: 10/17
# DEBUG:root:Jacknife_kriging_all_chosen: 11/17
# DEBUG:root:Jacknife_kriging_all_chosen: 12/17
# DEBUG:root:Jacknife_kriging_all_chosen: 13/17
# DEBUG:root:Jacknife_kriging_all_chosen: 14/17
# DEBUG:root:Jacknife_kriging_all_chosen: 15/17
# DEBUG:root:Jacknife_kriging_all_chosen: 16/17
# INFO:root:Jacknife category 12 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/137
# DEBUG:root:Jacknife_kriging_all_chosen: 1/137
# DEBUG:root:Jacknife_kriging_all_chosen: 2/137
# DEBUG:root:Jacknife_kriging_all_chosen: 3/137
# DEBUG:root:Jacknife_kriging_all_chosen: 4/137
# DEBUG:root:Jacknife_kriging_all_chosen: 5/137
# DEBUG:root:Jacknife_kriging_all_chosen: 6/137
# DEBUG:root:Jacknife_kriging_all_chosen: 7/137
# DEBUG:root:Jacknife_kriging_all_chosen: 8/137
# DEBUG:root:Jacknife_kriging_all_chosen: 9/137
# DEBUG:root:Jacknife_kriging_all_chosen: 10/137
# DEBUG:root:Jacknife_kriging_all_chosen: 11/137
# DEBUG:root:Jacknife_kriging_all_chosen: 12/137
# DEBUG:root:Jacknife_kriging_all_chosen: 13/137
# DEBUG:root:Jacknife_kriging_all_chosen: 14/137
# DEBUG:root:Jacknife_kriging_all_chosen: 15/137
# DEBUG:root:Jacknife_kriging_all_chosen: 16/137
# DEBUG:root:Jacknife_kriging_all_chosen: 17/137
# DEBUG:root:Jacknife_kriging_all_chosen: 18/137
# DEBUG:root:Jacknife_kriging_all_chosen: 19/137
# DEBUG:root:Jacknife_kriging_all_chosen: 20/137
# DEBUG:root:Jacknife_kriging_all_chosen: 21/137
# DEBUG:root:Jacknife_kriging_all_chosen: 22/137
# DEBUG:root:Jacknife_kriging_all_chosen: 23/137
# DEBUG:root:Jacknife_kriging_all_chosen: 24/137
# DEBUG:root:Jacknife_kriging_all_chosen: 25/137
# DEBUG:root:Jacknife_kriging_all_chosen: 26/137
# DEBUG:root:Jacknife_kriging_all_chosen: 27/137
# DEBUG:root:Jacknife_kriging_all_chosen: 28/137
# DEBUG:root:Jacknife_kriging_all_chosen: 29/137
# DEBUG:root:Jacknife_kriging_all_chosen: 30/137
# DEBUG:root:Jacknife_kriging_all_chosen: 31/137
# DEBUG:root:Jacknife_kriging_all_chosen: 32/137
# DEBUG:root:Jacknife_kriging_all_chosen: 33/137
# DEBUG:root:Jacknife_kriging_all_chosen: 34/137
# DEBUG:root:Jacknife_kriging_all_chosen: 35/137
# DEBUG:root:Jacknife_kriging_all_chosen: 36/137
# DEBUG:root:Jacknife_kriging_all_chosen: 37/137
# DEBUG:root:Jacknife_kriging_all_chosen: 38/137
# DEBUG:root:Jacknife_kriging_all_chosen: 39/137
# DEBUG:root:Jacknife_kriging_all_chosen: 40/137
# DEBUG:root:Jacknife_kriging_all_chosen: 41/137
# DEBUG:root:Jacknife_kriging_all_chosen: 42/137
# DEBUG:root:Jacknife_kriging_all_chosen: 43/137
# DEBUG:root:Jacknife_kriging_all_chosen: 44/137
# DEBUG:root:Jacknife_kriging_all_chosen: 45/137
# DEBUG:root:Jacknife_kriging_all_chosen: 46/137
# DEBUG:root:Jacknife_kriging_all_chosen: 47/137
# DEBUG:root:Jacknife_kriging_all_chosen: 48/137
# DEBUG:root:Jacknife_kriging_all_chosen: 49/137
# DEBUG:root:Jacknife_kriging_all_chosen: 50/137
# DEBUG:root:Jacknife_kriging_all_chosen: 51/137
# DEBUG:root:Jacknife_kriging_all_chosen: 52/137
# DEBUG:root:Jacknife_kriging_all_chosen: 53/137
# DEBUG:root:Jacknife_kriging_all_chosen: 54/137
# DEBUG:root:Jacknife_kriging_all_chosen: 55/137
# DEBUG:root:Jacknife_kriging_all_chosen: 56/137
# DEBUG:root:Jacknife_kriging_all_chosen: 57/137
# DEBUG:root:Jacknife_kriging_all_chosen: 58/137
# DEBUG:root:Jacknife_kriging_all_chosen: 59/137
# DEBUG:root:Jacknife_kriging_all_chosen: 60/137
# DEBUG:root:Jacknife_kriging_all_chosen: 61/137
# DEBUG:root:Jacknife_kriging_all_chosen: 62/137
# DEBUG:root:Jacknife_kriging_all_chosen: 63/137
# DEBUG:root:Jacknife_kriging_all_chosen: 64/137
# DEBUG:root:Jacknife_kriging_all_chosen: 65/137
# DEBUG:root:Jacknife_kriging_all_chosen: 66/137
# DEBUG:root:Jacknife_kriging_all_chosen: 67/137
# DEBUG:root:Jacknife_kriging_all_chosen: 68/137
# DEBUG:root:Jacknife_kriging_all_chosen: 69/137
# DEBUG:root:Jacknife_kriging_all_chosen: 70/137
# DEBUG:root:Jacknife_kriging_all_chosen: 71/137
# DEBUG:root:Jacknife_kriging_all_chosen: 72/137
# DEBUG:root:Jacknife_kriging_all_chosen: 73/137
# DEBUG:root:Jacknife_kriging_all_chosen: 74/137
# DEBUG:root:Jacknife_kriging_all_chosen: 75/137
# DEBUG:root:Jacknife_kriging_all_chosen: 76/137
# DEBUG:root:Jacknife_kriging_all_chosen: 77/137
# DEBUG:root:Jacknife_kriging_all_chosen: 78/137
# DEBUG:root:Jacknife_kriging_all_chosen: 79/137
# DEBUG:root:Jacknife_kriging_all_chosen: 80/137
# DEBUG:root:Jacknife_kriging_all_chosen: 81/137
# DEBUG:root:Jacknife_kriging_all_chosen: 82/137
# DEBUG:root:Jacknife_kriging_all_chosen: 83/137
# DEBUG:root:Jacknife_kriging_all_chosen: 84/137
# DEBUG:root:Jacknife_kriging_all_chosen: 85/137
# DEBUG:root:Jacknife_kriging_all_chosen: 86/137
# DEBUG:root:Jacknife_kriging_all_chosen: 87/137
# DEBUG:root:Jacknife_kriging_all_chosen: 88/137
# DEBUG:root:Jacknife_kriging_all_chosen: 89/137
# DEBUG:root:Jacknife_kriging_all_chosen: 90/137
# DEBUG:root:Jacknife_kriging_all_chosen: 91/137
# DEBUG:root:Jacknife_kriging_all_chosen: 92/137
# DEBUG:root:Jacknife_kriging_all_chosen: 93/137
# DEBUG:root:Jacknife_kriging_all_chosen: 94/137
# DEBUG:root:Jacknife_kriging_all_chosen: 95/137
# DEBUG:root:Jacknife_kriging_all_chosen: 96/137
# DEBUG:root:Jacknife_kriging_all_chosen: 97/137
# DEBUG:root:Jacknife_kriging_all_chosen: 98/137
# DEBUG:root:Jacknife_kriging_all_chosen: 99/137
# DEBUG:root:Jacknife_kriging_all_chosen: 100/137
# DEBUG:root:Jacknife_kriging_all_chosen: 101/137
# DEBUG:root:Jacknife_kriging_all_chosen: 102/137
# DEBUG:root:Jacknife_kriging_all_chosen: 103/137
# DEBUG:root:Jacknife_kriging_all_chosen: 104/137
# DEBUG:root:Jacknife_kriging_all_chosen: 105/137
# DEBUG:root:Jacknife_kriging_all_chosen: 106/137
# DEBUG:root:Jacknife_kriging_all_chosen: 107/137
# DEBUG:root:Jacknife_kriging_all_chosen: 108/137
# DEBUG:root:Jacknife_kriging_all_chosen: 109/137
# DEBUG:root:Jacknife_kriging_all_chosen: 110/137
# DEBUG:root:Jacknife_kriging_all_chosen: 111/137
# DEBUG:root:Jacknife_kriging_all_chosen: 112/137
# DEBUG:root:Jacknife_kriging_all_chosen: 113/137
# DEBUG:root:Jacknife_kriging_all_chosen: 114/137
# DEBUG:root:Jacknife_kriging_all_chosen: 115/137
# DEBUG:root:Jacknife_kriging_all_chosen: 116/137
# DEBUG:root:Jacknife_kriging_all_chosen: 117/137
# DEBUG:root:Jacknife_kriging_all_chosen: 118/137
# DEBUG:root:Jacknife_kriging_all_chosen: 119/137
# DEBUG:root:Jacknife_kriging_all_chosen: 120/137
# DEBUG:root:Jacknife_kriging_all_chosen: 121/137
# DEBUG:root:Jacknife_kriging_all_chosen: 122/137
# DEBUG:root:Jacknife_kriging_all_chosen: 123/137
# DEBUG:root:Jacknife_kriging_all_chosen: 124/137
# DEBUG:root:Jacknife_kriging_all_chosen: 125/137
# DEBUG:root:Jacknife_kriging_all_chosen: 126/137
# DEBUG:root:Jacknife_kriging_all_chosen: 127/137
# DEBUG:root:Jacknife_kriging_all_chosen: 128/137
# DEBUG:root:Jacknife_kriging_all_chosen: 129/137
# DEBUG:root:Jacknife_kriging_all_chosen: 130/137
# DEBUG:root:Jacknife_kriging_all_chosen: 131/137
# DEBUG:root:Jacknife_kriging_all_chosen: 132/137
# DEBUG:root:Jacknife_kriging_all_chosen: 133/137
# DEBUG:root:Jacknife_kriging_all_chosen: 134/137
# DEBUG:root:Jacknife_kriging_all_chosen: 135/137
# DEBUG:root:Jacknife_kriging_all_chosen: 136/137
# INFO:root:Jacknife category 13 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/4
# DEBUG:root:Jacknife_kriging_all_chosen: 1/4
# DEBUG:root:Jacknife_kriging_all_chosen: 2/4
# DEBUG:root:Jacknife_kriging_all_chosen: 3/4
# INFO:root:Jacknife category 14 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/7
# DEBUG:root:Jacknife_kriging_all_chosen: 1/7
# DEBUG:root:Jacknife_kriging_all_chosen: 2/7
# DEBUG:root:Jacknife_kriging_all_chosen: 3/7
# DEBUG:root:Jacknife_kriging_all_chosen: 4/7
# DEBUG:root:Jacknife_kriging_all_chosen: 5/7
# DEBUG:root:Jacknife_kriging_all_chosen: 6/7
# INFO:root:Jacknife category 15 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/12
# DEBUG:root:Jacknife_kriging_all_chosen: 1/12
# DEBUG:root:Jacknife_kriging_all_chosen: 2/12
# DEBUG:root:Jacknife_kriging_all_chosen: 3/12
# DEBUG:root:Jacknife_kriging_all_chosen: 4/12
# DEBUG:root:Jacknife_kriging_all_chosen: 5/12
# DEBUG:root:Jacknife_kriging_all_chosen: 6/12
# DEBUG:root:Jacknife_kriging_all_chosen: 7/12
# DEBUG:root:Jacknife_kriging_all_chosen: 8/12
# DEBUG:root:Jacknife_kriging_all_chosen: 9/12
# DEBUG:root:Jacknife_kriging_all_chosen: 10/12
# DEBUG:root:Jacknife_kriging_all_chosen: 11/12
# chosen 137 5 (5L,)
# not chosen 137 5 (5L,) (5L,)
# INFO:root:Jacknife category 0 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/145
# DEBUG:root:Jacknife_kriging_all_chosen: 1/145
# DEBUG:root:Jacknife_kriging_all_chosen: 2/145
# DEBUG:root:Jacknife_kriging_all_chosen: 3/145
# DEBUG:root:Jacknife_kriging_all_chosen: 4/145
# DEBUG:root:Jacknife_kriging_all_chosen: 5/145
# DEBUG:root:Jacknife_kriging_all_chosen: 6/145
# DEBUG:root:Jacknife_kriging_all_chosen: 7/145
# DEBUG:root:Jacknife_kriging_all_chosen: 8/145
# DEBUG:root:Jacknife_kriging_all_chosen: 9/145
# DEBUG:root:Jacknife_kriging_all_chosen: 10/145
# DEBUG:root:Jacknife_kriging_all_chosen: 11/145
# DEBUG:root:Jacknife_kriging_all_chosen: 12/145
# DEBUG:root:Jacknife_kriging_all_chosen: 13/145
# DEBUG:root:Jacknife_kriging_all_chosen: 14/145
# DEBUG:root:Jacknife_kriging_all_chosen: 15/145
# DEBUG:root:Jacknife_kriging_all_chosen: 16/145
# DEBUG:root:Jacknife_kriging_all_chosen: 17/145
# DEBUG:root:Jacknife_kriging_all_chosen: 18/145
# DEBUG:root:Jacknife_kriging_all_chosen: 19/145
# DEBUG:root:Jacknife_kriging_all_chosen: 20/145
# DEBUG:root:Jacknife_kriging_all_chosen: 21/145
# DEBUG:root:Jacknife_kriging_all_chosen: 22/145
# DEBUG:root:Jacknife_kriging_all_chosen: 23/145
# DEBUG:root:Jacknife_kriging_all_chosen: 24/145
# DEBUG:root:Jacknife_kriging_all_chosen: 25/145
# DEBUG:root:Jacknife_kriging_all_chosen: 26/145
# DEBUG:root:Jacknife_kriging_all_chosen: 27/145
# DEBUG:root:Jacknife_kriging_all_chosen: 28/145
# DEBUG:root:Jacknife_kriging_all_chosen: 29/145
# DEBUG:root:Jacknife_kriging_all_chosen: 30/145
# DEBUG:root:Jacknife_kriging_all_chosen: 31/145
# DEBUG:root:Jacknife_kriging_all_chosen: 32/145
# DEBUG:root:Jacknife_kriging_all_chosen: 33/145
# DEBUG:root:Jacknife_kriging_all_chosen: 34/145
# DEBUG:root:Jacknife_kriging_all_chosen: 35/145
# DEBUG:root:Jacknife_kriging_all_chosen: 36/145
# DEBUG:root:Jacknife_kriging_all_chosen: 37/145
# DEBUG:root:Jacknife_kriging_all_chosen: 38/145
# DEBUG:root:Jacknife_kriging_all_chosen: 39/145
# DEBUG:root:Jacknife_kriging_all_chosen: 40/145
# DEBUG:root:Jacknife_kriging_all_chosen: 41/145
# DEBUG:root:Jacknife_kriging_all_chosen: 42/145
# DEBUG:root:Jacknife_kriging_all_chosen: 43/145
# DEBUG:root:Jacknife_kriging_all_chosen: 44/145
# DEBUG:root:Jacknife_kriging_all_chosen: 45/145
# DEBUG:root:Jacknife_kriging_all_chosen: 46/145
# DEBUG:root:Jacknife_kriging_all_chosen: 47/145
# DEBUG:root:Jacknife_kriging_all_chosen: 48/145
# DEBUG:root:Jacknife_kriging_all_chosen: 49/145
# DEBUG:root:Jacknife_kriging_all_chosen: 50/145
# DEBUG:root:Jacknife_kriging_all_chosen: 51/145
# DEBUG:root:Jacknife_kriging_all_chosen: 52/145
# DEBUG:root:Jacknife_kriging_all_chosen: 53/145
# DEBUG:root:Jacknife_kriging_all_chosen: 54/145
# DEBUG:root:Jacknife_kriging_all_chosen: 55/145
# DEBUG:root:Jacknife_kriging_all_chosen: 56/145
# DEBUG:root:Jacknife_kriging_all_chosen: 57/145
# DEBUG:root:Jacknife_kriging_all_chosen: 58/145
# DEBUG:root:Jacknife_kriging_all_chosen: 59/145
# DEBUG:root:Jacknife_kriging_all_chosen: 60/145
# DEBUG:root:Jacknife_kriging_all_chosen: 61/145
# DEBUG:root:Jacknife_kriging_all_chosen: 62/145
# DEBUG:root:Jacknife_kriging_all_chosen: 63/145
# DEBUG:root:Jacknife_kriging_all_chosen: 64/145
# DEBUG:root:Jacknife_kriging_all_chosen: 65/145
# DEBUG:root:Jacknife_kriging_all_chosen: 66/145
# DEBUG:root:Jacknife_kriging_all_chosen: 67/145
# DEBUG:root:Jacknife_kriging_all_chosen: 68/145
# DEBUG:root:Jacknife_kriging_all_chosen: 69/145
# DEBUG:root:Jacknife_kriging_all_chosen: 70/145
# DEBUG:root:Jacknife_kriging_all_chosen: 71/145
# DEBUG:root:Jacknife_kriging_all_chosen: 72/145
# DEBUG:root:Jacknife_kriging_all_chosen: 73/145
# DEBUG:root:Jacknife_kriging_all_chosen: 74/145
# DEBUG:root:Jacknife_kriging_all_chosen: 75/145
# DEBUG:root:Jacknife_kriging_all_chosen: 76/145
# DEBUG:root:Jacknife_kriging_all_chosen: 77/145
# DEBUG:root:Jacknife_kriging_all_chosen: 78/145
# DEBUG:root:Jacknife_kriging_all_chosen: 79/145
# DEBUG:root:Jacknife_kriging_all_chosen: 80/145
# DEBUG:root:Jacknife_kriging_all_chosen: 81/145
# DEBUG:root:Jacknife_kriging_all_chosen: 82/145
# DEBUG:root:Jacknife_kriging_all_chosen: 83/145
# DEBUG:root:Jacknife_kriging_all_chosen: 84/145
# DEBUG:root:Jacknife_kriging_all_chosen: 85/145
# DEBUG:root:Jacknife_kriging_all_chosen: 86/145
# DEBUG:root:Jacknife_kriging_all_chosen: 87/145
# DEBUG:root:Jacknife_kriging_all_chosen: 88/145
# DEBUG:root:Jacknife_kriging_all_chosen: 89/145
# DEBUG:root:Jacknife_kriging_all_chosen: 90/145
# DEBUG:root:Jacknife_kriging_all_chosen: 91/145
# DEBUG:root:Jacknife_kriging_all_chosen: 92/145
# DEBUG:root:Jacknife_kriging_all_chosen: 93/145
# DEBUG:root:Jacknife_kriging_all_chosen: 94/145
# DEBUG:root:Jacknife_kriging_all_chosen: 95/145
# DEBUG:root:Jacknife_kriging_all_chosen: 96/145
# DEBUG:root:Jacknife_kriging_all_chosen: 97/145
# DEBUG:root:Jacknife_kriging_all_chosen: 98/145
# DEBUG:root:Jacknife_kriging_all_chosen: 99/145
# DEBUG:root:Jacknife_kriging_all_chosen: 100/145
# DEBUG:root:Jacknife_kriging_all_chosen: 101/145
# DEBUG:root:Jacknife_kriging_all_chosen: 102/145
# DEBUG:root:Jacknife_kriging_all_chosen: 103/145
# DEBUG:root:Jacknife_kriging_all_chosen: 104/145
# DEBUG:root:Jacknife_kriging_all_chosen: 105/145
# DEBUG:root:Jacknife_kriging_all_chosen: 106/145
# DEBUG:root:Jacknife_kriging_all_chosen: 107/145
# DEBUG:root:Jacknife_kriging_all_chosen: 108/145
# DEBUG:root:Jacknife_kriging_all_chosen: 109/145
# DEBUG:root:Jacknife_kriging_all_chosen: 110/145
# DEBUG:root:Jacknife_kriging_all_chosen: 111/145
# DEBUG:root:Jacknife_kriging_all_chosen: 112/145
# DEBUG:root:Jacknife_kriging_all_chosen: 113/145
# DEBUG:root:Jacknife_kriging_all_chosen: 114/145
# DEBUG:root:Jacknife_kriging_all_chosen: 115/145
# DEBUG:root:Jacknife_kriging_all_chosen: 116/145
# DEBUG:root:Jacknife_kriging_all_chosen: 117/145
# DEBUG:root:Jacknife_kriging_all_chosen: 118/145
# DEBUG:root:Jacknife_kriging_all_chosen: 119/145
# DEBUG:root:Jacknife_kriging_all_chosen: 120/145
# DEBUG:root:Jacknife_kriging_all_chosen: 121/145
# DEBUG:root:Jacknife_kriging_all_chosen: 122/145
# DEBUG:root:Jacknife_kriging_all_chosen: 123/145
# DEBUG:root:Jacknife_kriging_all_chosen: 124/145
# DEBUG:root:Jacknife_kriging_all_chosen: 125/145
# DEBUG:root:Jacknife_kriging_all_chosen: 126/145
# DEBUG:root:Jacknife_kriging_all_chosen: 127/145
# DEBUG:root:Jacknife_kriging_all_chosen: 128/145
# DEBUG:root:Jacknife_kriging_all_chosen: 129/145
# DEBUG:root:Jacknife_kriging_all_chosen: 130/145
# DEBUG:root:Jacknife_kriging_all_chosen: 131/145
# DEBUG:root:Jacknife_kriging_all_chosen: 132/145
# DEBUG:root:Jacknife_kriging_all_chosen: 133/145
# DEBUG:root:Jacknife_kriging_all_chosen: 134/145
# DEBUG:root:Jacknife_kriging_all_chosen: 135/145
# DEBUG:root:Jacknife_kriging_all_chosen: 136/145
# DEBUG:root:Jacknife_kriging_all_chosen: 137/145
# DEBUG:root:Jacknife_kriging_all_chosen: 138/145
# DEBUG:root:Jacknife_kriging_all_chosen: 139/145
# DEBUG:root:Jacknife_kriging_all_chosen: 140/145
# DEBUG:root:Jacknife_kriging_all_chosen: 141/145
# DEBUG:root:Jacknife_kriging_all_chosen: 142/145
# DEBUG:root:Jacknife_kriging_all_chosen: 143/145
# DEBUG:root:Jacknife_kriging_all_chosen: 144/145
# INFO:root:Jacknife category 1 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/8
# DEBUG:root:Jacknife_kriging_all_chosen: 1/8
# DEBUG:root:Jacknife_kriging_all_chosen: 2/8
# DEBUG:root:Jacknife_kriging_all_chosen: 3/8
# DEBUG:root:Jacknife_kriging_all_chosen: 4/8
# DEBUG:root:Jacknife_kriging_all_chosen: 5/8
# DEBUG:root:Jacknife_kriging_all_chosen: 6/8
# DEBUG:root:Jacknife_kriging_all_chosen: 7/8
# INFO:root:Jacknife category 2 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/17
# DEBUG:root:Jacknife_kriging_all_chosen: 1/17
# DEBUG:root:Jacknife_kriging_all_chosen: 2/17
# DEBUG:root:Jacknife_kriging_all_chosen: 3/17
# DEBUG:root:Jacknife_kriging_all_chosen: 4/17
# DEBUG:root:Jacknife_kriging_all_chosen: 5/17
# DEBUG:root:Jacknife_kriging_all_chosen: 6/17
# DEBUG:root:Jacknife_kriging_all_chosen: 7/17
# DEBUG:root:Jacknife_kriging_all_chosen: 8/17
# DEBUG:root:Jacknife_kriging_all_chosen: 9/17
# DEBUG:root:Jacknife_kriging_all_chosen: 10/17
# DEBUG:root:Jacknife_kriging_all_chosen: 11/17
# DEBUG:root:Jacknife_kriging_all_chosen: 12/17
# DEBUG:root:Jacknife_kriging_all_chosen: 13/17
# DEBUG:root:Jacknife_kriging_all_chosen: 14/17
# DEBUG:root:Jacknife_kriging_all_chosen: 15/17
# DEBUG:root:Jacknife_kriging_all_chosen: 16/17
# INFO:root:Jacknife category 3 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/125
# chosen 145 1 (1L,)
# not chosen 145 1 (1L,) (1L,)
# chosen 17 1 (1L,)
# not chosen 17 1 (1L,) (1L,)
# DEBUG:root:Jacknife_kriging_all_chosen: 1/125
# DEBUG:root:Jacknife_kriging_all_chosen: 2/125
# DEBUG:root:Jacknife_kriging_all_chosen: 3/125
# DEBUG:root:Jacknife_kriging_all_chosen: 4/125
# DEBUG:root:Jacknife_kriging_all_chosen: 5/125
# DEBUG:root:Jacknife_kriging_all_chosen: 6/125
# DEBUG:root:Jacknife_kriging_all_chosen: 7/125
# DEBUG:root:Jacknife_kriging_all_chosen: 8/125
# DEBUG:root:Jacknife_kriging_all_chosen: 9/125
# DEBUG:root:Jacknife_kriging_all_chosen: 10/125
# DEBUG:root:Jacknife_kriging_all_chosen: 11/125
# DEBUG:root:Jacknife_kriging_all_chosen: 12/125
# DEBUG:root:Jacknife_kriging_all_chosen: 13/125
# DEBUG:root:Jacknife_kriging_all_chosen: 14/125
# DEBUG:root:Jacknife_kriging_all_chosen: 15/125
# DEBUG:root:Jacknife_kriging_all_chosen: 16/125
# DEBUG:root:Jacknife_kriging_all_chosen: 17/125
# DEBUG:root:Jacknife_kriging_all_chosen: 18/125
# DEBUG:root:Jacknife_kriging_all_chosen: 19/125
# DEBUG:root:Jacknife_kriging_all_chosen: 20/125
# DEBUG:root:Jacknife_kriging_all_chosen: 21/125
# DEBUG:root:Jacknife_kriging_all_chosen: 22/125
# DEBUG:root:Jacknife_kriging_all_chosen: 23/125
# DEBUG:root:Jacknife_kriging_all_chosen: 24/125
# DEBUG:root:Jacknife_kriging_all_chosen: 25/125
# DEBUG:root:Jacknife_kriging_all_chosen: 26/125
# DEBUG:root:Jacknife_kriging_all_chosen: 27/125
# DEBUG:root:Jacknife_kriging_all_chosen: 28/125
# DEBUG:root:Jacknife_kriging_all_chosen: 29/125
# DEBUG:root:Jacknife_kriging_all_chosen: 30/125
# DEBUG:root:Jacknife_kriging_all_chosen: 31/125
# DEBUG:root:Jacknife_kriging_all_chosen: 32/125
# DEBUG:root:Jacknife_kriging_all_chosen: 33/125
# DEBUG:root:Jacknife_kriging_all_chosen: 34/125
# DEBUG:root:Jacknife_kriging_all_chosen: 35/125
# DEBUG:root:Jacknife_kriging_all_chosen: 36/125
# DEBUG:root:Jacknife_kriging_all_chosen: 37/125
# DEBUG:root:Jacknife_kriging_all_chosen: 38/125
# DEBUG:root:Jacknife_kriging_all_chosen: 39/125
# DEBUG:root:Jacknife_kriging_all_chosen: 40/125
# DEBUG:root:Jacknife_kriging_all_chosen: 41/125
# DEBUG:root:Jacknife_kriging_all_chosen: 42/125
# DEBUG:root:Jacknife_kriging_all_chosen: 43/125
# DEBUG:root:Jacknife_kriging_all_chosen: 44/125
# DEBUG:root:Jacknife_kriging_all_chosen: 45/125
# DEBUG:root:Jacknife_kriging_all_chosen: 46/125
# DEBUG:root:Jacknife_kriging_all_chosen: 47/125
# DEBUG:root:Jacknife_kriging_all_chosen: 48/125
# DEBUG:root:Jacknife_kriging_all_chosen: 49/125
# DEBUG:root:Jacknife_kriging_all_chosen: 50/125
# DEBUG:root:Jacknife_kriging_all_chosen: 51/125
# DEBUG:root:Jacknife_kriging_all_chosen: 52/125
# DEBUG:root:Jacknife_kriging_all_chosen: 53/125
# DEBUG:root:Jacknife_kriging_all_chosen: 54/125
# DEBUG:root:Jacknife_kriging_all_chosen: 55/125
# DEBUG:root:Jacknife_kriging_all_chosen: 56/125
# DEBUG:root:Jacknife_kriging_all_chosen: 57/125
# DEBUG:root:Jacknife_kriging_all_chosen: 58/125
# DEBUG:root:Jacknife_kriging_all_chosen: 59/125
# DEBUG:root:Jacknife_kriging_all_chosen: 60/125
# DEBUG:root:Jacknife_kriging_all_chosen: 61/125
# DEBUG:root:Jacknife_kriging_all_chosen: 62/125
# DEBUG:root:Jacknife_kriging_all_chosen: 63/125
# DEBUG:root:Jacknife_kriging_all_chosen: 64/125
# DEBUG:root:Jacknife_kriging_all_chosen: 65/125
# DEBUG:root:Jacknife_kriging_all_chosen: 66/125
# DEBUG:root:Jacknife_kriging_all_chosen: 67/125
# DEBUG:root:Jacknife_kriging_all_chosen: 68/125
# DEBUG:root:Jacknife_kriging_all_chosen: 69/125
# DEBUG:root:Jacknife_kriging_all_chosen: 70/125
# DEBUG:root:Jacknife_kriging_all_chosen: 71/125
# DEBUG:root:Jacknife_kriging_all_chosen: 72/125
# DEBUG:root:Jacknife_kriging_all_chosen: 73/125
# DEBUG:root:Jacknife_kriging_all_chosen: 74/125
# DEBUG:root:Jacknife_kriging_all_chosen: 75/125
# DEBUG:root:Jacknife_kriging_all_chosen: 76/125
# DEBUG:root:Jacknife_kriging_all_chosen: 77/125
# DEBUG:root:Jacknife_kriging_all_chosen: 78/125
# DEBUG:root:Jacknife_kriging_all_chosen: 79/125
# DEBUG:root:Jacknife_kriging_all_chosen: 80/125
# DEBUG:root:Jacknife_kriging_all_chosen: 81/125
# DEBUG:root:Jacknife_kriging_all_chosen: 82/125
# DEBUG:root:Jacknife_kriging_all_chosen: 83/125
# DEBUG:root:Jacknife_kriging_all_chosen: 84/125
# DEBUG:root:Jacknife_kriging_all_chosen: 85/125
# DEBUG:root:Jacknife_kriging_all_chosen: 86/125
# DEBUG:root:Jacknife_kriging_all_chosen: 87/125
# DEBUG:root:Jacknife_kriging_all_chosen: 88/125
# DEBUG:root:Jacknife_kriging_all_chosen: 89/125
# DEBUG:root:Jacknife_kriging_all_chosen: 90/125
# DEBUG:root:Jacknife_kriging_all_chosen: 91/125
# DEBUG:root:Jacknife_kriging_all_chosen: 92/125
# DEBUG:root:Jacknife_kriging_all_chosen: 93/125
# DEBUG:root:Jacknife_kriging_all_chosen: 94/125
# DEBUG:root:Jacknife_kriging_all_chosen: 95/125
# DEBUG:root:Jacknife_kriging_all_chosen: 96/125
# DEBUG:root:Jacknife_kriging_all_chosen: 97/125
# DEBUG:root:Jacknife_kriging_all_chosen: 98/125
# DEBUG:root:Jacknife_kriging_all_chosen: 99/125
# DEBUG:root:Jacknife_kriging_all_chosen: 100/125
# DEBUG:root:Jacknife_kriging_all_chosen: 101/125
# DEBUG:root:Jacknife_kriging_all_chosen: 102/125
# DEBUG:root:Jacknife_kriging_all_chosen: 103/125
# DEBUG:root:Jacknife_kriging_all_chosen: 104/125
# DEBUG:root:Jacknife_kriging_all_chosen: 105/125
# DEBUG:root:Jacknife_kriging_all_chosen: 106/125
# DEBUG:root:Jacknife_kriging_all_chosen: 107/125
# DEBUG:root:Jacknife_kriging_all_chosen: 108/125
# DEBUG:root:Jacknife_kriging_all_chosen: 109/125
# DEBUG:root:Jacknife_kriging_all_chosen: 110/125
# DEBUG:root:Jacknife_kriging_all_chosen: 111/125
# DEBUG:root:Jacknife_kriging_all_chosen: 112/125
# DEBUG:root:Jacknife_kriging_all_chosen: 113/125
# DEBUG:root:Jacknife_kriging_all_chosen: 114/125
# DEBUG:root:Jacknife_kriging_all_chosen: 115/125
# DEBUG:root:Jacknife_kriging_all_chosen: 116/125
# DEBUG:root:Jacknife_kriging_all_chosen: 117/125
# DEBUG:root:Jacknife_kriging_all_chosen: 118/125
# DEBUG:root:Jacknife_kriging_all_chosen: 119/125
# DEBUG:root:Jacknife_kriging_all_chosen: 120/125
# DEBUG:root:Jacknife_kriging_all_chosen: 121/125
# DEBUG:root:Jacknife_kriging_all_chosen: 122/125
# DEBUG:root:Jacknife_kriging_all_chosen: 123/125
# DEBUG:root:Jacknife_kriging_all_chosen: 124/125
# INFO:root:Jacknife category 4 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/40
# DEBUG:root:Jacknife_kriging_all_chosen: 1/40
# ...
# DEBUG:root:Jacknife_kriging_all_chosen: 18/55
# DEBUG:root:Jacknife_kriging_all_chosen: 19/55
# DEBUG:root:Jacknife_kriging_all_chosen: 20/55
# DEBUG:root:Jacknife_kriging_all_chosen: 21/55
# DEBUG:root:Jacknife_kriging_all_chosen: 22/55
# DEBUG:root:Jacknife_kriging_all_chosen: 23/55
# DEBUG:root:Jacknife_kriging_all_chosen: 24/55
# DEBUG:root:Jacknife_kriging_all_chosen: 25/55
# DEBUG:root:Jacknife_kriging_all_chosen: 26/55
# DEBUG:root:Jacknife_kriging_all_chosen: 27/55
# DEBUG:root:Jacknife_kriging_all_chosen: 28/55
# DEBUG:root:Jacknife_kriging_all_chosen: 29/55
# DEBUG:root:Jacknife_kriging_all_chosen: 30/55
# DEBUG:root:Jacknife_kriging_all_chosen: 31/55
# DEBUG:root:Jacknife_kriging_all_chosen: 32/55
# DEBUG:root:Jacknife_kriging_all_chosen: 33/55
# DEBUG:root:Jacknife_kriging_all_chosen: 34/55
# DEBUG:root:Jacknife_kriging_all_chosen: 35/55
# DEBUG:root:Jacknife_kriging_all_chosen: 36/55
# DEBUG:root:Jacknife_kriging_all_chosen: 37/55
# DEBUG:root:Jacknife_kriging_all_chosen: 38/55
# DEBUG:root:Jacknife_kriging_all_chosen: 39/55
# DEBUG:root:Jacknife_kriging_all_chosen: 40/55
# DEBUG:root:Jacknife_kriging_all_chosen: 41/55
# DEBUG:root:Jacknife_kriging_all_chosen: 42/55
# DEBUG:root:Jacknife_kriging_all_chosen: 43/55
# DEBUG:root:Jacknife_kriging_all_chosen: 44/55
# DEBUG:root:Jacknife_kriging_all_chosen: 45/55
# DEBUG:root:Jacknife_kriging_all_chosen: 46/55
# DEBUG:root:Jacknife_kriging_all_chosen: 47/55
# DEBUG:root:Jacknife_kriging_all_chosen: 48/55
# DEBUG:root:Jacknife_kriging_all_chosen: 49/55
# DEBUG:root:Jacknife_kriging_all_chosen: 50/55
# DEBUG:root:Jacknife_kriging_all_chosen: 51/55
# DEBUG:root:Jacknife_kriging_all_chosen: 52/55
# DEBUG:root:Jacknife_kriging_all_chosen: 53/55
# DEBUG:root:Jacknife_kriging_all_chosen: 54/55
# INFO:root:Jacknife category 6 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/19
# DEBUG:root:Jacknife_kriging_all_chosen: 1/19
# DEBUG:root:Jacknife_kriging_all_chosen: 2/19
# DEBUG:root:Jacknife_kriging_all_chosen: 3/19
# DEBUG:root:Jacknife_kriging_all_chosen: 4/19
# DEBUG:root:Jacknife_kriging_all_chosen: 5/19
# DEBUG:root:Jacknife_kriging_all_chosen: 6/19
# DEBUG:root:Jacknife_kriging_all_chosen: 7/19
# DEBUG:root:Jacknife_kriging_all_chosen: 8/19
# DEBUG:root:Jacknife_kriging_all_chosen: 9/19
# DEBUG:root:Jacknife_kriging_all_chosen: 10/19
# DEBUG:root:Jacknife_kriging_all_chosen: 11/19
# DEBUG:root:Jacknife_kriging_all_chosen: 12/19
# DEBUG:root:Jacknife_kriging_all_chosen: 13/19
# DEBUG:root:Jacknife_kriging_all_chosen: 14/19
# DEBUG:root:Jacknife_kriging_all_chosen: 15/19
# DEBUG:root:Jacknife_kriging_all_chosen: 16/19
# DEBUG:root:Jacknife_kriging_all_chosen: 17/19
# DEBUG:root:Jacknife_kriging_all_chosen: 18/19
# INFO:root:Jacknife category 7 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/32
# DEBUG:root:Jacknife_kriging_all_chosen: 1/32
# DEBUG:root:Jacknife_kriging_all_chosen: 2/32
# DEBUG:root:Jacknife_kriging_all_chosen: 3/32
# DEBUG:root:Jacknife_kriging_all_chosen: 4/32
# DEBUG:root:Jacknife_kriging_all_chosen: 5/32
# DEBUG:root:Jacknife_kriging_all_chosen: 6/32
# chosen 55 3 (3L,)
# not chosen 55 3 (3L,) (3L,)
# DEBUG:root:Jacknife_kriging_all_chosen: 7/32
# DEBUG:root:Jacknife_kriging_all_chosen: 8/32
# DEBUG:root:Jacknife_kriging_all_chosen: 9/32
# DEBUG:root:Jacknife_kriging_all_chosen: 10/32
# DEBUG:root:Jacknife_kriging_all_chosen: 11/32
# DEBUG:root:Jacknife_kriging_all_chosen: 12/32
# DEBUG:root:Jacknife_kriging_all_chosen: 13/32
# DEBUG:root:Jacknife_kriging_all_chosen: 14/32
# DEBUG:root:Jacknife_kriging_all_chosen: 15/32
# DEBUG:root:Jacknife_kriging_all_chosen: 16/32
# DEBUG:root:Jacknife_kriging_all_chosen: 17/32
# DEBUG:root:Jacknife_kriging_all_chosen: 18/32
# DEBUG:root:Jacknife_kriging_all_chosen: 19/32
# DEBUG:root:Jacknife_kriging_all_chosen: 20/32
# DEBUG:root:Jacknife_kriging_all_chosen: 21/32
# DEBUG:root:Jacknife_kriging_all_chosen: 22/32
# DEBUG:root:Jacknife_kriging_all_chosen: 23/32
# DEBUG:root:Jacknife_kriging_all_chosen: 24/32
# DEBUG:root:Jacknife_kriging_all_chosen: 25/32
# DEBUG:root:Jacknife_kriging_all_chosen: 26/32
# DEBUG:root:Jacknife_kriging_all_chosen: 27/32
# DEBUG:root:Jacknife_kriging_all_chosen: 28/32
# DEBUG:root:Jacknife_kriging_all_chosen: 29/32
# DEBUG:root:Jacknife_kriging_all_chosen: 30/32
# DEBUG:root:Jacknife_kriging_all_chosen: 31/32
# INFO:root:Jacknife category 8 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/61
# DEBUG:root:Jacknife_kriging_all_chosen: 1/61
# DEBUG:root:Jacknife_kriging_all_chosen: 2/61
# DEBUG:root:Jacknife_kriging_all_chosen: 3/61
# DEBUG:root:Jacknife_kriging_all_chosen: 4/61
# DEBUG:root:Jacknife_kriging_all_chosen: 5/61
# DEBUG:root:Jacknife_kriging_all_chosen: 6/61
# DEBUG:root:Jacknife_kriging_all_chosen: 7/61
# chosen 32 1 (1L,)
# not chosen 32 1 (1L,) (1L,)
# DEBUG:root:Jacknife_kriging_all_chosen: 8/61
# DEBUG:root:Jacknife_kriging_all_chosen: 9/61
# DEBUG:root:Jacknife_kriging_all_chosen: 10/61
# DEBUG:root:Jacknife_kriging_all_chosen: 11/61
# DEBUG:root:Jacknife_kriging_all_chosen: 12/61
# DEBUG:root:Jacknife_kriging_all_chosen: 13/61
# DEBUG:root:Jacknife_kriging_all_chosen: 14/61
# DEBUG:root:Jacknife_kriging_all_chosen: 15/61
# DEBUG:root:Jacknife_kriging_all_chosen: 16/61
# DEBUG:root:Jacknife_kriging_all_chosen: 17/61
# DEBUG:root:Jacknife_kriging_all_chosen: 18/61
# DEBUG:root:Jacknife_kriging_all_chosen: 19/61
# DEBUG:root:Jacknife_kriging_all_chosen: 20/61
# DEBUG:root:Jacknife_kriging_all_chosen: 21/61
# DEBUG:root:Jacknife_kriging_all_chosen: 22/61
# DEBUG:root:Jacknife_kriging_all_chosen: 23/61
# DEBUG:root:Jacknife_kriging_all_chosen: 24/61
# DEBUG:root:Jacknife_kriging_all_chosen: 25/61
# DEBUG:root:Jacknife_kriging_all_chosen: 26/61
# DEBUG:root:Jacknife_kriging_all_chosen: 27/61
# DEBUG:root:Jacknife_kriging_all_chosen: 28/61
# DEBUG:root:Jacknife_kriging_all_chosen: 29/61
# DEBUG:root:Jacknife_kriging_all_chosen: 30/61
# DEBUG:root:Jacknife_kriging_all_chosen: 31/61
# DEBUG:root:Jacknife_kriging_all_chosen: 32/61
# DEBUG:root:Jacknife_kriging_all_chosen: 33/61
# DEBUG:root:Jacknife_kriging_all_chosen: 34/61
# DEBUG:root:Jacknife_kriging_all_chosen: 35/61
# DEBUG:root:Jacknife_kriging_all_chosen: 36/61
# DEBUG:root:Jacknife_kriging_all_chosen: 37/61
# DEBUG:root:Jacknife_kriging_all_chosen: 38/61
# DEBUG:root:Jacknife_kriging_all_chosen: 39/61
# DEBUG:root:Jacknife_kriging_all_chosen: 40/61
# DEBUG:root:Jacknife_kriging_all_chosen: 41/61
# DEBUG:root:Jacknife_kriging_all_chosen: 42/61
# DEBUG:root:Jacknife_kriging_all_chosen: 43/61
# DEBUG:root:Jacknife_kriging_all_chosen: 44/61
# DEBUG:root:Jacknife_kriging_all_chosen: 45/61
# DEBUG:root:Jacknife_kriging_all_chosen: 46/61
# DEBUG:root:Jacknife_kriging_all_chosen: 47/61
# DEBUG:root:Jacknife_kriging_all_chosen: 48/61
# DEBUG:root:Jacknife_kriging_all_chosen: 49/61
# DEBUG:root:Jacknife_kriging_all_chosen: 50/61
# DEBUG:root:Jacknife_kriging_all_chosen: 51/61
# DEBUG:root:Jacknife_kriging_all_chosen: 52/61
# DEBUG:root:Jacknife_kriging_all_chosen: 53/61
# DEBUG:root:Jacknife_kriging_all_chosen: 54/61
# DEBUG:root:Jacknife_kriging_all_chosen: 55/61
# DEBUG:root:Jacknife_kriging_all_chosen: 56/61
# DEBUG:root:Jacknife_kriging_all_chosen: 57/61
# DEBUG:root:Jacknife_kriging_all_chosen: 58/61
# DEBUG:root:Jacknife_kriging_all_chosen: 59/61
# DEBUG:root:Jacknife_kriging_all_chosen: 60/61
# INFO:root:Jacknife category 9 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/6
# DEBUG:root:Jacknife_kriging_all_chosen: 1/6
# DEBUG:root:Jacknife_kriging_all_chosen: 2/6
# DEBUG:root:Jacknife_kriging_all_chosen: 3/6
# DEBUG:root:Jacknife_kriging_all_chosen: 4/6
# DEBUG:root:Jacknife_kriging_all_chosen: 5/6
# INFO:root:Jacknife category 10 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/4
# DEBUG:root:Jacknife_kriging_all_chosen: 1/4
# DEBUG:root:Jacknife_kriging_all_chosen: 2/4
# DEBUG:root:Jacknife_kriging_all_chosen: 3/4
# INFO:root:Jacknife category 11 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/17
# DEBUG:root:Jacknife_kriging_all_chosen: 1/17
# DEBUG:root:Jacknife_kriging_all_chosen: 2/17
# DEBUG:root:Jacknife_kriging_all_chosen: 3/17
# DEBUG:root:Jacknife_kriging_all_chosen: 4/17
# DEBUG:root:Jacknife_kriging_all_chosen: 5/17
# DEBUG:root:Jacknife_kriging_all_chosen: 6/17
# DEBUG:root:Jacknife_kriging_all_chosen: 7/17
# DEBUG:root:Jacknife_kriging_all_chosen: 8/17
# DEBUG:root:Jacknife_kriging_all_chosen: 9/17
# DEBUG:root:Jacknife_kriging_all_chosen: 10/17
# DEBUG:root:Jacknife_kriging_all_chosen: 11/17
# DEBUG:root:Jacknife_kriging_all_chosen: 12/17
# DEBUG:root:Jacknife_kriging_all_chosen: 13/17
# DEBUG:root:Jacknife_kriging_all_chosen: 14/17
# DEBUG:root:Jacknife_kriging_all_chosen: 15/17
# DEBUG:root:Jacknife_kriging_all_chosen: 16/17
# INFO:root:Jacknife category 12 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/131
# chosen 61 1 (1L,)
# not chosen 61 1 (1L,) (1L,)
# chosen 6 4 (4L,)
# not chosen 6 4 (4L,) (4L,)
# chosen 4 1 (1L,)
# not chosen 4 1 (1L,) (1L,)
# DEBUG:root:Jacknife_kriging_all_chosen: 1/131
# DEBUG:root:Jacknife_kriging_all_chosen: 2/131
# DEBUG:root:Jacknife_kriging_all_chosen: 3/131
# DEBUG:root:Jacknife_kriging_all_chosen: 4/131
# DEBUG:root:Jacknife_kriging_all_chosen: 5/131
# DEBUG:root:Jacknife_kriging_all_chosen: 6/131
# DEBUG:root:Jacknife_kriging_all_chosen: 7/131
# DEBUG:root:Jacknife_kriging_all_chosen: 8/131
# DEBUG:root:Jacknife_kriging_all_chosen: 9/131
# DEBUG:root:Jacknife_kriging_all_chosen: 10/131
# DEBUG:root:Jacknife_kriging_all_chosen: 11/131
# DEBUG:root:Jacknife_kriging_all_chosen: 12/131
# DEBUG:root:Jacknife_kriging_all_chosen: 13/131
# DEBUG:root:Jacknife_kriging_all_chosen: 14/131
# DEBUG:root:Jacknife_kriging_all_chosen: 15/131
# DEBUG:root:Jacknife_kriging_all_chosen: 16/131
# DEBUG:root:Jacknife_kriging_all_chosen: 17/131
# DEBUG:root:Jacknife_kriging_all_chosen: 18/131
# DEBUG:root:Jacknife_kriging_all_chosen: 19/131
# DEBUG:root:Jacknife_kriging_all_chosen: 20/131
# DEBUG:root:Jacknife_kriging_all_chosen: 21/131
# DEBUG:root:Jacknife_kriging_all_chosen: 22/131
# DEBUG:root:Jacknife_kriging_all_chosen: 23/131
# DEBUG:root:Jacknife_kriging_all_chosen: 24/131
# DEBUG:root:Jacknife_kriging_all_chosen: 25/131
# DEBUG:root:Jacknife_kriging_all_chosen: 26/131
# DEBUG:root:Jacknife_kriging_all_chosen: 27/131
# DEBUG:root:Jacknife_kriging_all_chosen: 28/131
# DEBUG:root:Jacknife_kriging_all_chosen: 29/131
# DEBUG:root:Jacknife_kriging_all_chosen: 30/131
# DEBUG:root:Jacknife_kriging_all_chosen: 31/131
# DEBUG:root:Jacknife_kriging_all_chosen: 32/131
# DEBUG:root:Jacknife_kriging_all_chosen: 33/131
# DEBUG:root:Jacknife_kriging_all_chosen: 34/131
# DEBUG:root:Jacknife_kriging_all_chosen: 35/131
# DEBUG:root:Jacknife_kriging_all_chosen: 36/131
# DEBUG:root:Jacknife_kriging_all_chosen: 37/131
# DEBUG:root:Jacknife_kriging_all_chosen: 38/131
# DEBUG:root:Jacknife_kriging_all_chosen: 39/131
# DEBUG:root:Jacknife_kriging_all_chosen: 40/131
# DEBUG:root:Jacknife_kriging_all_chosen: 41/131
# DEBUG:root:Jacknife_kriging_all_chosen: 42/131
# DEBUG:root:Jacknife_kriging_all_chosen: 43/131
# DEBUG:root:Jacknife_kriging_all_chosen: 44/131
# DEBUG:root:Jacknife_kriging_all_chosen: 45/131
# DEBUG:root:Jacknife_kriging_all_chosen: 46/131
# DEBUG:root:Jacknife_kriging_all_chosen: 47/131
# DEBUG:root:Jacknife_kriging_all_chosen: 48/131
# DEBUG:root:Jacknife_kriging_all_chosen: 49/131
# DEBUG:root:Jacknife_kriging_all_chosen: 50/131
# DEBUG:root:Jacknife_kriging_all_chosen: 51/131
# DEBUG:root:Jacknife_kriging_all_chosen: 52/131
# DEBUG:root:Jacknife_kriging_all_chosen: 53/131
# DEBUG:root:Jacknife_kriging_all_chosen: 54/131
# DEBUG:root:Jacknife_kriging_all_chosen: 55/131
# DEBUG:root:Jacknife_kriging_all_chosen: 56/131
# DEBUG:root:Jacknife_kriging_all_chosen: 57/131
# DEBUG:root:Jacknife_kriging_all_chosen: 58/131
# DEBUG:root:Jacknife_kriging_all_chosen: 59/131
# DEBUG:root:Jacknife_kriging_all_chosen: 60/131
# DEBUG:root:Jacknife_kriging_all_chosen: 61/131
# DEBUG:root:Jacknife_kriging_all_chosen: 62/131
# DEBUG:root:Jacknife_kriging_all_chosen: 63/131
# DEBUG:root:Jacknife_kriging_all_chosen: 64/131
# DEBUG:root:Jacknife_kriging_all_chosen: 65/131
# DEBUG:root:Jacknife_kriging_all_chosen: 66/131
# DEBUG:root:Jacknife_kriging_all_chosen: 67/131
# DEBUG:root:Jacknife_kriging_all_chosen: 68/131
# DEBUG:root:Jacknife_kriging_all_chosen: 69/131
# DEBUG:root:Jacknife_kriging_all_chosen: 70/131
# DEBUG:root:Jacknife_kriging_all_chosen: 71/131
# DEBUG:root:Jacknife_kriging_all_chosen: 72/131
# DEBUG:root:Jacknife_kriging_all_chosen: 73/131
# DEBUG:root:Jacknife_kriging_all_chosen: 74/131
# DEBUG:root:Jacknife_kriging_all_chosen: 75/131
# DEBUG:root:Jacknife_kriging_all_chosen: 76/131
# DEBUG:root:Jacknife_kriging_all_chosen: 77/131
# DEBUG:root:Jacknife_kriging_all_chosen: 78/131
# DEBUG:root:Jacknife_kriging_all_chosen: 79/131
# DEBUG:root:Jacknife_kriging_all_chosen: 80/131
# DEBUG:root:Jacknife_kriging_all_chosen: 81/131
# DEBUG:root:Jacknife_kriging_all_chosen: 82/131
# DEBUG:root:Jacknife_kriging_all_chosen: 83/131
# DEBUG:root:Jacknife_kriging_all_chosen: 84/131
# DEBUG:root:Jacknife_kriging_all_chosen: 85/131
# DEBUG:root:Jacknife_kriging_all_chosen: 86/131
# DEBUG:root:Jacknife_kriging_all_chosen: 87/131
# DEBUG:root:Jacknife_kriging_all_chosen: 88/131
# DEBUG:root:Jacknife_kriging_all_chosen: 89/131
# DEBUG:root:Jacknife_kriging_all_chosen: 90/131
# DEBUG:root:Jacknife_kriging_all_chosen: 91/131
# DEBUG:root:Jacknife_kriging_all_chosen: 92/131
# DEBUG:root:Jacknife_kriging_all_chosen: 93/131
# DEBUG:root:Jacknife_kriging_all_chosen: 94/131
# DEBUG:root:Jacknife_kriging_all_chosen: 95/131
# DEBUG:root:Jacknife_kriging_all_chosen: 96/131
# DEBUG:root:Jacknife_kriging_all_chosen: 97/131
# DEBUG:root:Jacknife_kriging_all_chosen: 98/131
# DEBUG:root:Jacknife_kriging_all_chosen: 99/131
# DEBUG:root:Jacknife_kriging_all_chosen: 100/131
# DEBUG:root:Jacknife_kriging_all_chosen: 101/131
# DEBUG:root:Jacknife_kriging_all_chosen: 102/131
# DEBUG:root:Jacknife_kriging_all_chosen: 103/131
# DEBUG:root:Jacknife_kriging_all_chosen: 104/131
# DEBUG:root:Jacknife_kriging_all_chosen: 105/131
# DEBUG:root:Jacknife_kriging_all_chosen: 106/131
# DEBUG:root:Jacknife_kriging_all_chosen: 107/131
# DEBUG:root:Jacknife_kriging_all_chosen: 108/131
# DEBUG:root:Jacknife_kriging_all_chosen: 109/131
# DEBUG:root:Jacknife_kriging_all_chosen: 110/131
# DEBUG:root:Jacknife_kriging_all_chosen: 111/131
# DEBUG:root:Jacknife_kriging_all_chosen: 112/131
# DEBUG:root:Jacknife_kriging_all_chosen: 113/131
# DEBUG:root:Jacknife_kriging_all_chosen: 114/131
# DEBUG:root:Jacknife_kriging_all_chosen: 115/131
# DEBUG:root:Jacknife_kriging_all_chosen: 116/131
# DEBUG:root:Jacknife_kriging_all_chosen: 117/131
# DEBUG:root:Jacknife_kriging_all_chosen: 118/131
# DEBUG:root:Jacknife_kriging_all_chosen: 119/131
# DEBUG:root:Jacknife_kriging_all_chosen: 120/131
# DEBUG:root:Jacknife_kriging_all_chosen: 121/131
# DEBUG:root:Jacknife_kriging_all_chosen: 122/131
# DEBUG:root:Jacknife_kriging_all_chosen: 123/131
# DEBUG:root:Jacknife_kriging_all_chosen: 124/131
# DEBUG:root:Jacknife_kriging_all_chosen: 125/131
# DEBUG:root:Jacknife_kriging_all_chosen: 126/131
# DEBUG:root:Jacknife_kriging_all_chosen: 127/131
# DEBUG:root:Jacknife_kriging_all_chosen: 128/131
# DEBUG:root:Jacknife_kriging_all_chosen: 129/131
# DEBUG:root:Jacknife_kriging_all_chosen: 130/131
# INFO:root:Jacknife category 13 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/4
# DEBUG:root:Jacknife_kriging_all_chosen: 1/4
# DEBUG:root:Jacknife_kriging_all_chosen: 2/4
# DEBUG:root:Jacknife_kriging_all_chosen: 3/4
# INFO:root:Jacknife category 14 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/7
# DEBUG:root:Jacknife_kriging_all_chosen: 1/7
# DEBUG:root:Jacknife_kriging_all_chosen: 2/7
# DEBUG:root:Jacknife_kriging_all_chosen: 3/7
# DEBUG:root:Jacknife_kriging_all_chosen: 4/7
# DEBUG:root:Jacknife_kriging_all_chosen: 5/7
# DEBUG:root:Jacknife_kriging_all_chosen: 6/7
# INFO:root:Jacknife category 15 label 1
# DEBUG:root:Jacknife_kriging_all_chosen: 0/12
# DEBUG:root:Jacknife_kriging_all_chosen: 1/12
# DEBUG:root:Jacknife_kriging_all_chosen: 2/12
# DEBUG:root:Jacknife_kriging_all_chosen: 3/12
# DEBUG:root:Jacknife_kriging_all_chosen: 4/12
# DEBUG:root:Jacknife_kriging_all_chosen: 5/12
# DEBUG:root:Jacknife_kriging_all_chosen: 6/12
# DEBUG:root:Jacknife_kriging_all_chosen: 7/12
# DEBUG:root:Jacknife_kriging_all_chosen: 8/12
# DEBUG:root:Jacknife_kriging_all_chosen: 9/12
# DEBUG:root:Jacknife_kriging_all_chosen: 10/12
# DEBUG:root:Jacknife_kriging_all_chosen: 11/12
# chosen 131 11 (11L,)
# not chosen 131 11 (11L,) (11L,)
# Solving kriging system for category 1 with no. points 3149 677

# %% [markdown]
# ## Interpolation
# To run the actual interpolation, the `predict` method of the `MLEKrigor` is used. It takes, longitude, latitude and category as main input. In addition, $\lambda_w$ needs to be specified.  This mainly affects the obtained uncertainties. If desired, the full covariance matrix can also be calculated, but due to memory constraints, by default only the variance (main diagonal) is computed.
#
# Note that `predict` does not respect the shape of the input points and the outputs needs to be reshaped. Furtheremore, the **variance** of the error is returned (to be compatible with the full covariance case) not the standard deviation!

# %%
cat_grid = np.ones(lonGrid.shape,dtype=int)

pred,krigvar,predPars = krigor.predict(lonGrid.flatten(),latGrid.flatten(),cat_grid.flatten(),
                                       lambda_w=100.0,get_covar=False)

pred = pred.reshape(lonGrid.shape)
krigvar = krigvar.reshape(lonGrid.shape)
# Out:
# Solving kriging system for category 1 with no. points 3149 699

# %%
plt.figure()
plt.contourf(lonGrid,latGrid,pred)
cbar = plt.colorbar()
cbar.set_label('Moho depth [km]')
plt.axis('equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.figure()
plt.contourf(lonGrid,latGrid,np.sqrt(krigvar))
cbar = plt.colorbar()
cbar.set_label('Moho uncertainty [km]')
plt.axis('equal')
# Out:
# (-81.0, -35.0, -54.0, 12.0)

# %% [markdown]
# Note that in this case, one should not interpret results in the oceanic domain, since they were excluded from the interpolation.
